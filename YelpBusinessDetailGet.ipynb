# %%
import os
import requests
import json

# %%
def get_business_details(api_key, business_id):
    url = f"https://api.yelp.com/v3/businesses/{business_id}"
    headers = {"Authorization": f"Bearer {api_key}"}
    response = requests.get(url, headers=headers)
    business_data = response.json()
    return business_data

# %%
Yelp_api_key = os.getenv('YELP_API_KEY_2')

# %% [markdown]
# 1. All Hotels

# %%
#load all hotels from dataset Hotels.jsonl
hotels = []

# Open the file and read it line by line
with open('Datasets/Hotels.jsonl', 'r') as file:
    for line in file:
        # Parse each line as a JSON object and append to the list
        json_obj = json.loads(line.strip())  # strip() removes any leading/trailing whitespace
        hotels.append(json_obj)

assert len(hotels) == 107

# %%
hotels_detail = []

for hotel in hotels:
    business_id = hotel['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    hotels_detail.append(detail)

# %%
with open('Datasets/Hotels_detail.jsonl', 'w') as json_file:    
    for item in hotels_detail:
        json.dump(item, json_file)
        json_file.write('\n')

# %% [markdown]
# 2. Attractions

# %%
#load all hotels from dataset Hotels.jsonl
attractions = []

# Open the file and read it line by line
with open('Datasets/Attractions.jsonl', 'r') as file:
    for line in file:
        # Parse each line as a JSON object and append to the list
        json_obj = json.loads(line.strip())  # strip() removes any leading/trailing whitespace
        attractions.append(json_obj)

assert len(attractions) == 346

# %%
attractions_before300 = attractions[:300]

# %%
attractions_detail = []

for attraction in attractions_before300:
    business_id = attraction['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    attractions_detail.append(detail)

# %%
with open('Datasets/Attractions_detail.jsonl', 'w') as json_file:    
    for item in attractions_detail:
        json.dump(item, json_file)
        json_file.write('\n')

# %%
#get the elements after first 300 records
attractions_after300 = attractions[300:]
attractions_after300
# Out:
# [{'business_id': 'nA6zjguOkl4bYNv3deSbUA',
#   'name': 'Museum Hack',
#   'address': '',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19130',
#   'latitude': 39.9682609,
#   'longitude': -75.1749671,
#   'stars': 5.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'WiFi': "u'free'",
#    'BusinessAcceptsBitcoin': 'True'},
#   'categories': 'Tours, Event Planning & Services, Team Building Activities, Active Life, Hotels & Travel, Scavenger Hunts',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  {'business_id': '4V6BpKsB68F9W8MQSfe1Zg',
#   'name': 'Lincoln Financial Field Tours',
#   'address': 'One Lincoln Financial Field Way',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19148',
#   'latitude': 39.900998,
# ...

# %%
attractions_detail = []

for attraction in attractions_after300:
    business_id = attraction['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    attractions_detail.append(detail)

# %%
with open('Datasets/Attractions_detail.jsonl', 'a') as json_file:    
    for item in attractions_detail:
        json.dump(item, json_file)
        json_file.write('\n')

# %% [markdown]
# 3. all restaurants

# %%
#first 200 Restaurants
restaurants = []

with open('Datasets/Restaurants_top1000.jsonl', 'r') as file:
    for line in file:
        # Parse each line as a JSON object and append to the list
        json_obj = json.loads(line.strip())  # strip() removes any leading/trailing whitespace
        restaurants.append(json_obj)

assert len(restaurants) == 1000

# %% [markdown]
# 1-200

# %%
restaurants_first200 = restaurants[:200]
len(restaurants_first200)
# Out:
# 200

# %%
restaurants_first200_detail = []

for restaurant in restaurants_first200:
    business_id = restaurant['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    restaurants_first200_detail.append(detail)

# %%
len(restaurants_first200_detail)
# Out:
# 200

# %%
with open('Datasets/Restaurants_top1000_detail.jsonl', 'w') as json_file:    
    for item in restaurants_first200_detail:
        json.dump(item, json_file)
        json_file.write('\n')

# %% [markdown]
# 200-500

# %%
restaurants_200_500 = restaurants[200:500]
len(restaurants_200_500)
# Out:
# 300

# %%
restaurants_200_500[0]
# Out:
# {'business_id': '_f3JQU6IXpGmTLaSqGy79g',
#  'name': 'BRÜ Craft & Wurst',
#  'address': '1318 Chestnut St',
#  'city': 'Philadelphia',
#  'state': 'PA',
#  'postal_code': '19107',
#  'latitude': 39.9503152253,
#  'longitude': -75.1624865435,
#  'stars': 3.5,
#  'review_count': 526,
#  'is_open': 1,
#  'attributes': {'BusinessAcceptsCreditCards': 'True',
#   'RestaurantsGoodForGroups': 'True',
#   'RestaurantsPriceRange2': '2',
#   'RestaurantsTakeOut': 'True',
#   'RestaurantsReservations': 'True',
#   'WiFi': "'free'",
#   'BikeParking': 'True',
#   'HasTV': 'True',
#   'NoiseLevel': "u'loud'",
#   'RestaurantsAttire': "u'casual'",
#   'Caters': 'False',
#   'GoodForKids': 'False',
#   'RestaurantsTableService': 'True',
#   'HappyHour': 'True',
#   'OutdoorSeating': 'True',
#   'BestNights': "{'monday': False, 'tuesday': False, 'friday': True, 'wednesday': True, 'thursday': False, 'sunday': False, 'saturday': True}",
# ...

# %%
restaurants_200_500[-1]
# Out:
# {'business_id': 'eY8exh1aLVVhW6z_M0u_Eg',
#  'name': 'Pho Ha Saigon',
#  'address': '575 Adams Ave',
#  'city': 'Philadelphia',
#  'state': 'PA',
#  'postal_code': '19120',
#  'latitude': 40.0359369248,
#  'longitude': -75.107954232,
#  'stars': 3.5,
#  'review_count': 259,
#  'is_open': 1,
#  'attributes': {'NoiseLevel': "'average'",
#   'WiFi': "'no'",
#   'GoodForKids': 'True',
#   'RestaurantsReservations': 'True',
#   'HasTV': 'False',
#   'RestaurantsTableService': 'True',
#   'Alcohol': "'none'",
#   'RestaurantsTakeOut': 'True',
#   'BusinessAcceptsBitcoin': 'False',
#   'RestaurantsPriceRange2': '1',
#   'RestaurantsGoodForGroups': 'True',
#   'Caters': 'True',
#   'RestaurantsAttire': "'casual'",
#   'DogsAllowed': 'False',
#   'BikeParking': 'False',
#   'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
# ...

# %%
restaurants_200_500_detail = []

for restaurant in restaurants_200_500:
    business_id = restaurant['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    restaurants_200_500_detail.append(detail)

# %%
len(restaurants_200_500_detail)
# Out:
# 300

# %%
restaurants_200_500_detail[0]
# Out:
# {'id': '_f3JQU6IXpGmTLaSqGy79g',
#  'alias': 'brü-craft-and-wurst-philadelphia',
#  'name': 'BRÜ Craft & Wurst',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PglCb6lNvqyPRYIe8Fv2fQ/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/br%C3%BC-craft-and-wurst-philadelphia?adjust_creative=JrLmLqxHGo9rF1hfVPjqPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=JrLmLqxHGo9rF1hfVPjqPQ',
#  'phone': '+12158001079',
#  'display_phone': '(215) 800-1079',
#  'review_count': 568,
#  'categories': [{'alias': 'bars', 'title': 'Bars'},
#   {'alias': 'german', 'title': 'German'}],
#  'rating': 3.5,
#  'location': {'address1': '1318 Chestnut St',
#   'address2': '',
#   'address3': '',
#   'city': 'Philadelphia',
#   'zip_code': '19107',
#   'country': 'US',
#   'state': 'PA',
#   'display_address': ['1318 Chestnut St', 'Philadelphia, PA 19107'],
#   'cross_streets': ''},
# ...

# %%
restaurants_200_500_detail[-1]
# Out:
# {'id': 'eY8exh1aLVVhW6z_M0u_Eg',
#  'alias': 'pho-ha-saigon-philadelphia-2',
#  'name': 'Pho Ha Saigon',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_r5k33lBMOKvQFSkQvqQtA/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/pho-ha-saigon-philadelphia-2?adjust_creative=JrLmLqxHGo9rF1hfVPjqPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=JrLmLqxHGo9rF1hfVPjqPQ',
#  'phone': '+12675385600',
#  'display_phone': '(267) 538-5600',
#  'review_count': 304,
#  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#  'rating': 3.4,
#  'location': {'address1': '575 Adams Ave',
#   'address2': '',
#   'address3': '',
#   'city': 'Philadelphia',
#   'zip_code': '19120',
#   'country': 'US',
#   'state': 'PA',
#   'display_address': ['575 Adams Ave', 'Philadelphia, PA 19120'],
#   'cross_streets': ''},
#  'coordinates': {'latitude': 40.0359369247627, 'longitude': -75.1079542319922},
#  'photos': [],
# ...

# %%
with open('Datasets/Restaurants_top1000_detail.jsonl', 'a') as json_file:    
    for item in restaurants_200_500_detail:
        json.dump(item, json_file)
        json_file.write('\n')

# %% [markdown]
# 500-800

# %%
restaurants_500_800 = restaurants[500:800]
len(restaurants_500_800)
# Out:
# 300

# %%
restaurants_500_800[0]
# Out:
# {'business_id': 'GVZUe3iXg75_Zp9ZS91y9g',
#  'name': 'El Fuego',
#  'address': '723 Walnut St',
#  'city': 'Philadelphia',
#  'state': 'PA',
#  'postal_code': '19106',
#  'latitude': 39.9481,
#  'longitude': -75.1535615,
#  'stars': 3.5,
#  'review_count': 258,
#  'is_open': 1,
#  'attributes': {'BusinessAcceptsCreditCards': 'True',
#   'RestaurantsReservations': 'False',
#   'RestaurantsDelivery': 'True',
#   'WiFi': "u'no'",
#   'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#   'RestaurantsAttire': "'casual'",
#   'RestaurantsTakeOut': 'True',
#   'Caters': 'True',
#   'OutdoorSeating': 'False',
#   'GoodForKids': 'True',
#   'RestaurantsPriceRange2': '1',
#   'RestaurantsGoodForGroups': 'True',
#   'BYOBCorkage': "'no'",
#   'Alcohol': "'none'",
#   'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#   'NoiseLevel': "u'average'",
# ...

# %%
restaurants_500_800[-1]
# Out:
# {'business_id': '9PCiyXCG25bOycCR7nXIDw',
#  'name': "Santucci's Original Square Pizza",
#  'address': '655 N Broad St',
#  'city': 'Philadelphia',
#  'state': 'PA',
#  'postal_code': '19123',
#  'latitude': 39.96531,
#  'longitude': -75.16039,
#  'stars': 3.0,
#  'review_count': 162,
#  'is_open': 1,
#  'attributes': {'RestaurantsReservations': 'True',
#   'BikeParking': 'False',
#   'WheelchairAccessible': 'True',
#   'Alcohol': "u'full_bar'",
#   'RestaurantsPriceRange2': '2',
#   'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#   'BusinessAcceptsBitcoin': 'False',
#   'HasTV': 'True',
#   'RestaurantsTableService': 'True',
#   'DogsAllowed': 'False',
#   'RestaurantsDelivery': 'True',
#   'RestaurantsAttire': "u'casual'",
#   'HappyHour': 'True',
#   'BusinessAcceptsCreditCards': 'False',
#   'WiFi': "u'free'",
#   'NoiseLevel': "u'average'",
#   'Caters': 'True',
#   'RestaurantsGoodForGroups': 'True',
# ...

# %%
restaurants_500_800_detail = []

for restaurant in restaurants_500_800:
    business_id = restaurant['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    restaurants_500_800_detail.append(detail)

# %%
restaurants_500_800_detail[-1]
# Out:
# {'id': '9PCiyXCG25bOycCR7nXIDw',
#  'alias': 'santuccis-original-square-pizza-philadelphia-4',
#  'name': "Santucci's Original Square Pizza",
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3PcmgUGH7xACxg7XGNplEg/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/santuccis-original-square-pizza-philadelphia-4?adjust_creative=7Qh2N9ByxbyIDRiutbihsw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=7Qh2N9ByxbyIDRiutbihsw',
#  'phone': '+12676396014',
#  'display_phone': '(267) 639-6014',
#  'review_count': 195,
#  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#   {'alias': 'italian', 'title': 'Italian'}],
#  'rating': 3.2,
#  'location': {'address1': '655 N Broad St',
#   'address2': None,
#   'address3': '',
#   'city': 'Philadelphia',
#   'zip_code': '19123',
#   'country': 'US',
#   'state': 'PA',
#   'display_address': ['655 N Broad St', 'Philadelphia, PA 19123'],
#   'cross_streets': ''},
# ...

# %%
with open('Datasets/Restaurants_top1000_detail.jsonl', 'a') as json_file:    
    for item in restaurants_500_800_detail:
        json.dump(item, json_file)
        json_file.write('\n')

# %% [markdown]
# 800-1000

# %%
restaurants_after800 = restaurants[800:]
len(restaurants_after800)
# Out:
# 200

# %%
restaurants_after800_detail = []

for restaurant in restaurants_after800:
    business_id = restaurant['business_id']
    detail = get_business_details(Yelp_api_key, business_id)
    restaurants_after800_detail.append(detail)

# %%
restaurants_after800_detail[-1]
# Out:
# {'id': 'GKNknnI7pZgPwjOKNI9NPQ',
#  'alias': 'lucky-13-pub-philadelphia',
#  'name': 'Lucky 13 Pub',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fwLyO11n-SiMQsP0H2S-Pw/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/lucky-13-pub-philadelphia?adjust_creative=YdUq-dicqQkhZLKJNx4eHg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=YdUq-dicqQkhZLKJNx4eHg',
#  'phone': '+12153368467',
#  'display_phone': '(215) 336-8467',
#  'review_count': 139,
#  'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#   {'alias': 'newamerican', 'title': 'New American'}],
#  'rating': 3.9,
#  'location': {'address1': '1820 S 13th St',
#   'address2': '',
#   'address3': '',
#   'city': 'Philadelphia',
#   'zip_code': '19148',
#   'country': 'US',
#   'state': 'PA',
#   'display_address': ['1820 S 13th St', 'Philadelphia, PA 19148'],
#   'cross_streets': ''},
#  'coordinates': {'latitude': 39.92716, 'longitude': -75.16713},
# ...

# %%
with open('Datasets/Restaurants_top1000_detail.jsonl', 'a') as json_file:    
    for item in restaurants_after800_detail:
        json.dump(item, json_file)
        json_file.write('\n')
