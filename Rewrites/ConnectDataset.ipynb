# %%
import os
import json

def loadbase():
    with open ('Dataset/Base/Restaurants.jsonl', 'r') as file:
        restaurants = [json.loads(line.strip()) for line in file]

    with open ('Dataset/Base/Hotels.jsonl', 'r') as file:
        hotels = [json.loads(line.strip()) for line in file]

    with open ('Dataset/Base/Attractions.jsonl', 'r') as file:
        attractions = [json.loads(line.strip()) for line in file]

        return restaurants, hotels, attractions

def clean_attraction(attraction):
    level_map = {
        0: "no",
        1: "low",
        2: "medium",
        3: "high"
    }
    keys = []
    values = []
    for key, value in attraction.items():
        keys.append(key)
        values.append(value['level'])

    parsed = {}

    for i in range(len(keys)):
        new = {keys[i].replace('_',' '): level_map[values[i]] + ' ' + keys[i].replace('_',' ')}
        parsed = {**parsed, **new}

    return parsed

def parseAttraction(model,attractions_base):
    folder_path = f'preprocess/{model}/attractions'
    attractions_final = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            business_id_fromReviews = filename[:-5][-22:]
            
            for attraction in attractions_base:
                if attraction['business_id'] == business_id_fromReviews:
                    with open(folder_path + '/' + filename, 'r') as file:
                        attraction_fromReviews = json.load(file)
                    attraction_fromReviews_short = clean_attraction(attraction_fromReviews)
                    attraction_final = {**attraction, **attraction_fromReviews_short}
                    attractions_final.append(attraction_final)
    
    with open (f'Dataset/{model}/attractions.jsonl','w') as file:
        for item in attractions_final:
            json.dump(item, file)
            file.write('\n') 

    return attractions_final


def clean_hotel(hotel):
    level_map = {
        1 : "bad",
        2 : "below average",
        3 : "average",
        4 : "good",
        5 : "excellent"
    }
    keys = []
    values = []
    for key, value in hotel.items():
        keys.append(key)
        values.append(value['rating'])

    parsed = {}

    for i in range(len(keys)):
        new = {keys[i]: level_map[values[i]] + ' ' + keys[i]}
        parsed = {**parsed, **new}

    return parsed

def parseHotel(model,hotels_base):
    folder_path = f'preprocess/{model}/hotels'
    hotels_final = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.json'):
            business_id_fromReviews = filename[:-5][-22:]
            
            for hotel in hotels_base:
                if hotel['business_id'] == business_id_fromReviews:
                    with open(folder_path + '/' + filename, 'r') as file:
                        hotel_fromReviews = json.load(file)
                    hotel_fromReviews_short = clean_hotel(hotel_fromReviews)
                    hotel_final = {**hotel, **hotel_fromReviews_short}
                    hotels_final.append(hotel_final)
    
    with open (f'Dataset/{model}/hotels.jsonl','w') as file:
        for item in hotels_final:
            json.dump(item, file)
            file.write('\n') 

    return hotels_final


if __name__ == '__main__':
    model = 'gpt4o'
    restaurants_base, hotels_base, attractions_base = loadbase()

    attractions_final = parseAttraction(model,attractions_base)
    hotels_final = parseHotel(model,hotels_base)

# %%
hotels_final
# Out:
# [{'business_id': '-D_3emciINpjvYXsHCf8OA',
#   'name': 'AKA Rittenhouse Square',
#   'address': '135 S 18th St',
#   'latitude': 39.9503652,
#   'longitude': -75.1704529,
#   'stars': 4.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'oZxSL3PFX15Lzr8cjszmgQ',
#   'name': 'AKA University City',
#   'address': '2929 Walnut St',
#   'latitude': 39.951936,
#   'longitude': -75.183911,
#   'stars': 4.0,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': '3QPAh9VvYNTnqAFgBeBcng',
#   'name': 'Alexander Inn',
#   'address': '301 S 12th St',
#   'latitude': 39.946396818,
#   'longitude': -75.1609669488,
#   'stars': 4.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': '6I_DA3uqOox50rBvjrQ_-g',
#   'name': 'Aloft Philadelphia Airport',
#   'address': '4301 Island Ave',
#   'latitude': 39.8911246892,
#   'longitude': -75.2342512699,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'EaBgGhjd8rB9KVvCXKaiAw',
#   'name': 'Aloft Philadelphia Downtown',
#   'address': '101 North Broad St',
#   'latitude': 39.9546225,
#   'longitude': -75.1627921,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'Tb-TrnvMd0iSA2AMHLyGEQ',
#   'name': 'Best Western Plus Philadelphia Convention Center Hotel',
#   'address': '1225 Vine St',
#   'latitude': 39.957823,
#   'longitude': -75.159432,
#   'stars': 2.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'toEYTrafM81UMo2GyCSxFw',
#   'name': 'Cambria Hotel Philadelphia Downtown Center City',
#   'address': '219 South Broad Street',
#   'latitude': 39.9486052,
#   'longitude': -75.1640808,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'ZLjUCF2UaML7S5pSmn5BKg',
#   'name': 'Canopy by Hilton Philadelphia Center City',
#   'address': '1180 Ludlow St',
#   'latitude': 39.9509385644,
#   'longitude': -75.1599574301,
#   'stars': 4.5,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'excellent safety'},
#  {'business_id': 's7GZ95hHqmr9WreRU62iBQ',
#   'name': 'Chestnut Hill Hotel',
#   'address': '8229 Germantown Ave',
#   'latitude': 40.0741672,
#   'longitude': -75.2030982,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': '5CCWbCvlxPCX3kLSSFTfEA',
#   'name': 'Chestnut Hill Tower Apartments',
#   'address': '7600 Stenton Ave',
#   'latitude': 40.0732581,
#   'longitude': -75.1906974,
#   'stars': 2.0,
#   'price': 'Unknown price',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'bad service',
#   'safety': 'below average safety'},
#  {'business_id': 'Je10gqBQIqSvYNS8XGrYnw',
#   'name': 'Chez Colette',
#   'address': '120 S 17th St',
#   'latitude': 39.9507208157,
#   'longitude': -75.1689343926,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'good service',
#   'safety': 'average safety'},
#  {'business_id': 'p6H295aQCbDJ80GcpqFvwA',
#   'name': 'Club Quarters Philadelphia',
#   'address': '1628 Chestnut St',
#   'latitude': 39.9512939,
#   'longitude': -75.1684401,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'average safety'},
#  {'business_id': 'taVKq3N2vPxeNAHYDJAL5g',
#   'name': 'Cornerstone Bed & Breakfast',
#   'address': '3300 Baring St',
#   'latitude': 39.9613129,
#   'longitude': -75.1899803,
#   'stars': 4.5,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'excellent safety'},
#  {'business_id': 'MdxSCDMlOPZ2peHIDUZSFg',
#   'name': 'Courtyard by Marriott Philadelphia Airport',
#   'address': '8900 Bartram Ave',
#   'latitude': 39.8849770662,
#   'longitude': -75.2513694763,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'QMHd6Z2djm_SBLzGhLvFqw',
#   'name': 'Courtyard by Marriott Philadelphia South at The Navy Yard',
#   'address': '1001 Intrepid Ave',
#   'latitude': 39.895454514,
#   'longitude': -75.1717264504,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'average location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'j7dMQazjHXoBTsbpw5B28Q',
#   'name': 'Courtyard by Marriott',
#   'address': '4100 Presidential Blvd',
#   'latitude': 40.0071725342,
#   'longitude': -75.2110841091,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'bTNwrkDJ2HSIQo5egSX37g',
#   'name': 'Days Inn by Wyndham Philadelphia - Roosevelt Boulevard',
#   'address': '4200 Roosevelt Blvd',
#   'latitude': 40.029927,
#   'longitude': -75.1062366,
#   'stars': 1.0,
#   'price': '$',
#   'quality': 'bad quality',
#   'location': 'below average location',
#   'service': 'bad service',
#   'safety': 'bad safety'},
#  {'business_id': '0hVf3a0oq8ckB8JIDwSgig',
#   'name': 'Days Inn by Wyndham Philadelphia Convention Center',
#   'address': '1227 Race Street',
#   'latitude': 39.956112,
#   'longitude': -75.1602156,
#   'stars': 2.0,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'HVOHC7EyUMYdgV7S6kd0uQ',
#   'name': 'Delta Hotels Philadelphia Airport',
#   'address': '500 Stevens Dr',
#   'latitude': 39.8730999989,
#   'longitude': -75.2747963729,
#   'stars': 2.0,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': '7WD63dyoVXKdCFb9ly5EhA',
#   'name': 'DoubleTree by Hilton Hotel Philadelphia Airport',
#   'address': '4509 Island Ave',
#   'latitude': 39.8889615,
#   'longitude': -75.2325572,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'average safety'},
#  {'business_id': 'jTI5Xjk27An8ceJ6VwpXiQ',
#   'name': 'DoubleTree by Hilton Hotel Philadelphia Center City',
#   'address': '237 S Broad St',
#   'latitude': 39.9479028004,
#   'longitude': -75.1640327275,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'HF1YWT8QVR7095r-aLbV5g',
#   'name': 'Element Philadelphia',
#   'address': '1441 Chestnut St',
#   'latitude': 39.9511572392,
#   'longitude': -75.1653848735,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'SEFujmfGZI08JWRyhIpYeQ',
#   'name': 'Embassy Suites by Hilton Philadelphia Airport',
#   'address': '9000 Bartram Ave',
#   'latitude': 39.8838478195,
#   'longitude': -75.2497038245,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': '53ZvKaO19YS6Gt5x-va0BA',
#   'name': 'Extended Stay America - Philadelphia - Airport - Bartram Ave.',
#   'address': '8880 Bartram Ave.',
#   'latitude': 39.8862681,
#   'longitude': -75.2480428,
#   'stars': 1.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'vAjNHtuCm1Pwu47PEOTwXA',
#   'name': 'Extended Stay America - Philadelphia - Airport - Tinicum Blvd.',
#   'address': '9000 Tinicum Blvd',
#   'latitude': 39.8840025672,
#   'longitude': -75.2481961274,
#   'stars': 1.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'jDds2solrdvoyK7sB97Eog',
#   'name': 'Fairfield Inn & Suites Philadelphia Downtown/Center City',
#   'address': '261 South 13th Street',
#   'latitude': 39.9468905,
#   'longitude': -75.1623589,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'average safety'},
#  {'business_id': 'TTgpKmTSJs1w60DJkWlLWw',
#   'name': 'Fairfield Inn by Marriott Philadelphia Airport',
#   'address': '8800 Bartram Ave',
#   'latitude': 39.8868252585,
#   'longitude': -75.2476465702,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'good service',
#   'safety': 'average safety'},
#  {'business_id': 'tvBz80VKCtWAVbA6VmJufg',
#   'name': 'Four Points by Sheraton Philadelphia Airport',
#   'address': '4101A Island Ave',
#   'latitude': 39.8915307681,
#   'longitude': -75.2326749154,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'bad quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'KGvGSfvlWzurRu247ckEPw',
#   'name': 'Four Points by Sheraton Philadelphia City Center',
#   'address': '1201 Race St',
#   'latitude': 39.9560366,
#   'longitude': -75.1591784,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'THeEPb1SgJLhwMlWrxOeSQ',
#   'name': 'Four Points by Sheraton Philadelphia Northeast',
#   'address': '9461 Roosevelt Blvd',
#   'latitude': 40.0783729453,
#   'longitude': -75.0292557658,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'egk4EEv8KcmI6ZFyUieVeQ',
#   'name': 'Four Seasons Hotel Philadelphia at Comcast Center',
#   'address': '1 N 19th St',
#   'latitude': 39.9550013332,
#   'longitude': -75.170976,
#   'stars': 4.0,
#   'price': 'Unknown price',
#   'quality': 'excellent quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'sBZClv18j7gr1HIGIMXNcA',
#   'name': 'Hampton Inn Philadelphia Center City-Convention Center',
#   'address': '1301 Race St',
#   'latitude': 39.9562835951,
#   'longitude': -75.1607483625,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'wDaZZM-R-DvhoWR8y8q0mg',
#   'name': 'Hampton Inn Philadelphia-International Airport',
#   'address': '8600 Bartram Ave',
#   'latitude': 39.8882535601,
#   'longitude': -75.2463403344,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'dkxCH6f6-YXsmfWDEiZs-Q',
#   'name': 'Hawthorn Suites By Wyndham Philadelphia Airport',
#   'address': '4630 Island Avenue',
#   'latitude': 39.8884,
#   'longitude': -75.230898,
#   'stars': 2.0,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'JKR09pJneafnwpUg0FNEzw',
#   'name': 'Hilton Garden Inn Philadelphia Center City',
#   'address': '1100 Arch St',
#   'latitude': 39.9535723,
#   'longitude': -75.1580853,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'kM0CewxK3Ize1SF92bfJYQ',
#   'name': "Hilton Philadelphia at Penn's Landing",
#   'address': '201 S Christopher Columbus Blvd',
#   'latitude': 39.9452425,
#   'longitude': -75.1413550139,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'VEsI9_aDFzIrk8wh0QCOAw',
#   'name': 'Hilton Philadelphia City Avenue',
#   'address': '4200 City Ave',
#   'latitude': 40.004346,
#   'longitude': -75.21854,
#   'stars': 2.5,
#   'price': '$$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'average safety'},
#  {'business_id': 'xV32Y7jne4duaM3H_r_ryQ',
#   'name': 'Holiday Inn Express Philadelphia - Penns Landing',
#   'address': '100 N Columbus Blvd',
#   'latitude': 39.9528054,
#   'longitude': -75.140446,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'NvaHGU03m-hvXIGScPe6WQ',
#   'name': 'Holiday Inn Express Philadelphia-Midtown',
#   'address': '1305 Walnut St',
#   'latitude': 39.9493353797,
#   'longitude': -75.1626115157,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'fJhOwBljOz3VJV-BhCB3hg',
#   'name': 'Home2 Suites by Hilton Philadelphia - Convention Center, PA',
#   'address': '1200 Arch St',
#   'latitude': 39.9536826978,
#   'longitude': -75.159804225,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'tPu6ZX94n260wQprRVohvA',
#   'name': 'Homewood Suites by Hilton Philadelphia-City Avenue',
#   'address': '4200 City Ave',
#   'latitude': 40.0040060418,
#   'longitude': -75.217685797,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'X_1PaKwj4GhqwZ9Fi22WRA',
#   'name': 'Homewood Suites by Hilton University City Philadelphia, PA',
#   'address': '4109 Walnut St',
#   'latitude': 39.9546572,
#   'longitude': -75.205593,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'jMqEQYBIztLtcvnTujfHUA',
#   'name': 'Hyatt Centric Center City Philadelphia',
#   'address': '1620 Chancellor St',
#   'latitude': 39.9493052,
#   'longitude': -75.1689368,
#   'stars': 4.0,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'X_AVbwQcF3dcSWP6TlErcw',
#   'name': 'Independence Park Hotel, Bw Premier Collection',
#   'address': '235 Chestnut St',
#   'latitude': 39.9486694089,
#   'longitude': -75.145468139,
#   'stars': 4.5,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'sHumMO208xz2rMKYD-TrPA',
#   'name': 'Keystone Concierge',
#   'address': '',
#   'latitude': 39.9396284,
#   'longitude': -75.1866396,
#   'stars': 4.5,
#   'price': 'Unknown price',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'excellent safety'},
#  {'business_id': '2oav5QoWgnvTI2gO5xFMjw',
#   'name': 'Kimpton Hotel Monaco Philadelphia',
#   'address': '433 Chestnut St',
#   'latitude': 39.9491236494,
#   'longitude': -75.1488953439,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'A9El2DdT9Qx2tfFc_f279A',
#   'name': 'Kimpton Hotel Palomar Philadelphia',
#   'address': '117 S 17th St',
#   'latitude': 39.9508293,
#   'longitude': -75.1686289,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'Qy8eNnWB1bTYnvRQ9jgOOQ',
#   'name': 'Le Meridien Philadelphia',
#   'address': '1421 Arch Street',
#   'latitude': 39.9548246,
#   'longitude': -75.1640644,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': '_8QkK3WwGxNnn54Q1VTTcA',
#   'name': "Leneghan's Crusader Inn",
#   'address': '7412 Frankford Ave',
#   'latitude': 40.0382627,
#   'longitude': -75.0376145,
#   'stars': 5.0,
#   'price': '$',
#   'quality': 'average quality',
#   'location': 'average location',
#   'service': 'good service',
#   'safety': 'average safety'},
#  {'business_id': 'Q5-CkgsvtlRF5GphtoBFRQ',
#   'name': 'Live Casino Hotel',
#   'address': '900 Packer Ave',
#   'latitude': 39.9091912,
#   'longitude': -75.1646617,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'good safety'},
#  {'business_id': '0FMOvA2Noq-gieWfnXB7aQ',
#   'name': 'Live! Casino & Hotel Philadelphia',
#   'address': '900 Packer Ave',
#   'latitude': 39.9091912,
#   'longitude': -75.1646617,
#   'stars': 2.5,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'D5V0Fawd6ODVgqCY8xngsw',
#   'name': 'Loews Philadelphia Hotel',
#   'address': '1200 Market St',
#   'latitude': 39.9517461,
#   'longitude': -75.1602286,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'mlb7G66nkwYddPBfldUtIQ',
#   'name': 'Lokal Hotel',
#   'address': '139 N 3rd St',
#   'latitude': 39.9532548,
#   'longitude': -75.14479,
#   'stars': 4.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'good location',
#   'service': 'good service',
#   'safety': 'excellent safety'},
#  {'business_id': 'EMviUh7Lud2nqnarrqi_tQ',
#   'name': 'Microtel Inn & Suites by Wyndham Philadelphia Airport',
#   'address': '8840 Tinicum Boulevard',
#   'latitude': 39.8889605,
#   'longitude': -75.2457544,
#   'stars': 2.0,
#   'price': '$',
#   'quality': 'bad quality',
#   'location': 'below average location',
#   'service': 'bad service',
#   'safety': 'bad safety'},
#  {'business_id': '9VEnlasR3YppxZuDyUv3iA',
#   'name': 'Microtel Inn & Suites',
#   'address': '8840 Tincm Ave',
#   'latitude': 39.88692,
#   'longitude': -75.24655,
#   'stars': 2.5,
#   'price': 'Unknown price',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'bad safety'},
#  {'business_id': 'SO8kTCSO5dP5KyaX1JHDiA',
#   'name': 'Minute Suites',
#   'address': 'Terminal A-B Link',
#   'latitude': 39.8789176098,
#   'longitude': -75.235748291,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': '4UZgIeaRWuOj3Z6LNMyaDA',
#   'name': 'Morris House Hotel',
#   'address': '225 S 8th St',
#   'latitude': 39.9473689,
#   'longitude': -75.1542873,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': '_AVG0GvrMfBRK5jyuwSwrg',
#   'name': 'Motto By Hilton Philadelphia Rittenhouse Square',
#   'address': '31 S 19th St',
#   'latitude': 39.9525065,
#   'longitude': -75.1717068,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'qluIWCzDpeZfddykm_2gYg',
#   'name': 'North American Motor Inns',
#   'address': '4444 City Ave',
#   'latitude': 40.0031369,
#   'longitude': -75.2213329,
#   'stars': 1.0,
#   'price': '$',
#   'quality': 'bad quality',
#   'location': 'below average location',
#   'service': 'bad service',
#   'safety': 'bad safety'},
#  {'business_id': '0bvtIbpsqBJZpRKSPwIfNw',
#   'name': 'Panorama',
#   'address': '14 N Front St',
#   'latitude': 39.950201,
#   'longitude': -75.142285,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'excellent safety'},
#  {'business_id': 'HjewUoIXMm7yLu3aqQVTLg',
#   'name': 'Peking Inn',
#   'address': '2020 Penrose Ave, Ste D',
#   'latitude': 39.911958,
#   'longitude': -75.183405,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'lxIJfx79uxpR27Mly3lZ0Q',
#   'name': 'Penn Tower Hotel',
#   'address': '3400 Civic Center Blvd',
#   'latitude': 39.948655197,
#   'longitude': -75.1919810278,
#   'stars': 1.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'average safety'},
#  {'business_id': 'KGBjEO-FilXoCK_Pk-jsvA',
#   'name': "Penn's View Hotel",
#   'address': '14 N Front St',
#   'latitude': 39.950201,
#   'longitude': -75.142285,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'AXinWDle4ZYGtkdwqkBETQ',
#   'name': 'Penrose Hotel',
#   'address': '2033 Penrose Ave',
#   'latitude': 39.912507,
#   'longitude': -75.18395,
#   'stars': 1.0,
#   'price': '$$$',
#   'quality': 'bad quality',
#   'location': 'below average location',
#   'service': 'bad service',
#   'safety': 'bad safety'},
#  {'business_id': 'd9T1Jgf4N2vY3dcMlnCgeA',
#   'name': 'Philadelphia Airport Marriott',
#   'address': 'One Arrivals Road, Terminal B',
#   'latitude': 39.877788,
#   'longitude': -75.244411,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'uTZNjhXe5yCTMuEEN_xwEQ',
#   'name': 'Philadelphia Hotel Bella Vista',
#   'address': '752 S 10th St',
#   'latitude': 39.9403402,
#   'longitude': -75.1594404,
#   'stars': 3.5,
#   'price': '$',
#   'quality': 'below average quality',
#   'location': 'excellent location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'lZX5_8qspEXtMJGFQ0-Mow',
#   'name': 'Philadelphia Marriott Downtown',
#   'address': '1201 Market Street, (guest entrance at 1200 Filbert Street).',
#   'latitude': 39.952534,
#   'longitude': -75.160578,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'zJErbOQMKX-MwHs_ulV7DA',
#   'name': 'Philadelphia Marriott Old City',
#   'address': 'One Dock St, 2nd and Walnut St',
#   'latitude': 39.9452460633,
#   'longitude': -75.1433300972,
#   'stars': 3.0,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': '8XtpIfn6bjrzKQraKuZHEQ',
#   'name': 'Renaissance Philadelphia Downtown Hotel',
#   'address': '401 Chestnut St',
#   'latitude': 39.9490202,
#   'longitude': -75.1478095,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'average safety'},
#  {'business_id': 'JIrsBVXBPGeW5hRZvX7ZuA',
#   'name': 'Residence Inn by Marriott Philadelphia Center City',
#   'address': 'One East Penn Sq',
#   'latitude': 39.9526484795,
#   'longitude': -75.1624528099,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'dSdnWJxvhLwvsDfRI1lKuQ',
#   'name': 'Residence Inn Philadelphia Airport',
#   'address': '3701 Island Ave',
#   'latitude': 39.8957530955,
#   'longitude': -75.2363016307,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'n4Ns3xLRhpkRwglwiQGKVA',
#   'name': 'Rodeway Inn Center City',
#   'address': '1208 Walnut St',
#   'latitude': 39.948766,
#   'longitude': -75.161061,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'bad service',
#   'safety': 'below average safety'},
#  {'business_id': 'Pd-r2emx-k0GB3f2Iv4-zA',
#   'name': 'Roosevelt Inn',
#   'address': '7600 Roosevelt Blvd, Ste 1',
#   'latitude': 40.0507104,
#   'longitude': -75.0519427,
#   'stars': 2.0,
#   'price': '$$',
#   'quality': 'bad quality',
#   'location': 'below average location',
#   'service': 'below average service',
#   'safety': 'bad safety'},
#  {'business_id': 'd_AEJ6ekjX79tL5RZtwZ_g',
#   'name': 'ROOST Apartment Hotel',
#   'address': '111 S 15th St',
#   'latitude': 39.9505683,
#   'longitude': -75.1657016,
#   'stars': 4.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'UeoR9zNgHzBFFVvbq_44MQ',
#   'name': 'ROOST East Market',
#   'address': '1199 Ludlow St',
#   'latitude': 39.9513351232,
#   'longitude': -75.1597861201,
#   'stars': 4.5,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': '1QlgJVS-WEb9KGS42sQMIA',
#   'name': 'ROOST Rittenhouse',
#   'address': '1831 Chestnut St',
#   'latitude': 39.9520087,
#   'longitude': -75.1715201,
#   'stars': 4.0,
#   'price': 'Unknown price',
#   'quality': 'excellent quality',
#   'location': 'excellent location',
#   'service': 'excellent service',
#   'safety': 'good safety'},
#  {'business_id': 'TDLkD6gOkn1jJ93go1ZySQ',
#   'name': 'Sheraton Philadelphia Downtown',
#   'address': '201 North 17th Street',
#   'latitude': 39.9570991,
#   'longitude': -75.1670329,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'xcySfsPDols3EdtFC6b76g',
#   'name': 'Sheraton Philadelphia University City Hotel',
#   'address': '3549 Chestnut St',
#   'latitude': 39.954872,
#   'longitude': -75.194173,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'ppEDJRsyGcFqBw10STGDqw',
#   'name': 'Sheraton Suites Philadelphia Airport',
#   'address': '4101 B Island Ave',
#   'latitude': 39.890563284,
#   'longitude': -75.2315340866,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'below average safety'},
#  {'business_id': 'zy2p8yfx_fgXMCCUo8nWsA',
#   'name': 'Sleep Inn Center City',
#   'address': '1020 Cherry St',
#   'latitude': 39.9546067076,
#   'longitude': -75.157443872,
#   'stars': 3.5,
#   'price': '$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'good service',
#   'safety': 'average safety'},
#  {'business_id': 'QX3g1tCeHvb_kIhLmtBj0A',
#   'name': 'Society Hill Hotel',
#   'address': '301 Chestnut St',
#   'latitude': 39.9488102,
#   'longitude': -75.1461255,
#   'stars': 2.0,
#   'price': '$',
#   'quality': 'bad quality',
#   'location': 'good location',
#   'service': 'bad service',
#   'safety': 'bad safety'},
#  {'business_id': 'EgI6S-JxwpxICPsqmaggiw',
#   'name': 'Sofitel Philadelphia',
#   'address': '120 S 17th St',
#   'latitude': 39.9509482,
#   'longitude': -75.1695409,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'average safety'},
#  {'business_id': 'YGVBacpj1YW4q69hlYKoVA',
#   'name': 'Sonesta Philadelphia Rittenhouse Square',
#   'address': '1800 Market St',
#   'latitude': 39.9525251125,
#   'longitude': -75.1697713137,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'pFMGXlE1NwEXYPBgw3kRnA',
#   'name': 'Southern Inn',
#   'address': '5741 Woodland Ave',
#   'latitude': 39.9326866,
#   'longitude': -75.2245579,
#   'stars': 4.0,
#   'price': '$',
#   'quality': 'average quality',
#   'location': 'below average location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'cdZf-iYQRy5D18gTM95aew',
#   'name': 'The Bellevue Hotel',
#   'address': '200 S Broad St',
#   'latitude': 39.9491188,
#   'longitude': -75.1648441,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': '_BTdfZLpjdkdXwA-JuLwhw',
#   'name': 'The Conwell Inn',
#   'address': '1331 Pollet Walk',
#   'latitude': 39.981812,
#   'longitude': -75.15764,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'mKJZREPhvsVgHebHK8dFew',
#   'name': 'The Dwight D',
#   'address': '256 S 16th St',
#   'latitude': 39.9479893,
#   'longitude': -75.1682766,
#   'stars': 4.5,
#   'price': '$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'excellent safety'},
#  {'business_id': 'M4y3CIkX3uG9HPN4ZNqD_g',
#   'name': 'The Franklin Residences',
#   'address': '834 Chestnut St',
#   'latitude': 39.9493831,
#   'longitude': -75.1551309,
#   'stars': 5.0,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'excellent service',
#   'safety': 'excellent safety'},
#  {'business_id': '4hM6GbEq5Jt-YZ0vRN1-Lw',
#   'name': 'The Gables',
#   'address': '4520 Chester Ave',
#   'latitude': 39.9468926,
#   'longitude': -75.2121474,
#   'stars': 5.0,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'good location',
#   'service': 'excellent service',
#   'safety': 'good safety'},
#  {'business_id': 'bjkA3ustWdg3EsTLRiUNKA',
#   'name': 'The Inn at Penn, a Hilton Hotel',
#   'address': '3600 Sansom St',
#   'latitude': 39.9537829039,
#   'longitude': -75.1957815881,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'FppJo5aymUsfOg68uTOipw',
#   'name': 'The Inn at The Union League',
#   'address': '1450 Sansom',
#   'latitude': 39.9502330538,
#   'longitude': -75.1651874081,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'CFlW9bfl4N63fZpQsZIkRQ',
#   'name': 'The Logan Philadelphia, Curio Collection by Hilton',
#   'address': '1 Logan Sq',
#   'latitude': 39.9569323,
#   'longitude': -75.1702705,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'below average service',
#   'safety': 'good safety'},
#  {'business_id': 'xTCSNzu7387VHOPO7DkEzA',
#   'name': 'The Notary Hotel, Autograph Collection',
#   'address': '21 N Juniper St',
#   'latitude': 39.9530827357,
#   'longitude': -75.1621869785,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': '55gCXlWDDCdttR3yRss1xw',
#   'name': 'The Rittenhouse Hotel',
#   'address': '210 W Rittenhouse Sq',
#   'latitude': 39.9499125,
#   'longitude': -75.1736448,
#   'stars': 4.0,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'excellent safety'},
#  {'business_id': 'dvph41fD_t6Kd_ChSpmNSA',
#   'name': 'The Ritz-Carlton, Philadelphia',
#   'address': '10 Avenue of the Arts',
#   'latitude': 39.9514456414,
#   'longitude': -75.1641494036,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'fUntC7lbyc2VR3np-29D4g',
#   'name': 'The Spa at The Logan',
#   'address': '1 Logan Square',
#   'latitude': 39.956853,
#   'longitude': -75.169558,
#   'stars': 4.0,
#   'price': 'Unknown price',
#   'quality': 'average quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'NK0_YatQwVmIFJJyrdNNpQ',
#   'name': 'The Study at University City',
#   'address': '20 S 33rd St',
#   'latitude': 39.9544058,
#   'longitude': -75.1900591,
#   'stars': 4.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': '6gdAMPGsK0D_3u8h3A8H2A',
#   'name': 'The Warwick Hotel Rittenhouse Square',
#   'address': '220 S 17th St',
#   'latitude': 39.9486999512,
#   'longitude': -75.1694030762,
#   'stars': 3.0,
#   'price': '$$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'below average service',
#   'safety': 'below average safety'},
#  {'business_id': 'VJpuuNZ8QXR2zTHIhB0yhw',
#   'name': 'The Westin Philadelphia',
#   'address': '99 South 17th Street at Liberty Place',
#   'latitude': 39.951929,
#   'longitude': -75.168421,
#   'stars': 3.0,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'below average service',
#   'safety': 'average safety'},
#  {'business_id': 'HsBN0LiWQnbcltRIOWOslg',
#   'name': 'The Windsor Suites',
#   'address': '1700 Benjamin Franklin Pkwy',
#   'latitude': 39.9557404,
#   'longitude': -75.1683553,
#   'stars': 3.5,
#   'price': '$$',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'below average service',
#   'safety': 'average safety'},
#  {'business_id': 'YrbQ_OrRo-TYHnVw5y4Kew',
#   'name': 'Thomas Bond House',
#   'address': '129 S 2nd St',
#   'latitude': 39.9474906,
#   'longitude': -75.1440147,
#   'stars': 4.5,
#   'price': 'Unknown price',
#   'quality': 'average quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'good safety'},
#  {'business_id': 'S2ljhPVQb8wxIN98j0Stcw',
#   'name': 'Tokio Sushi Bistro & Bed & Breakfast',
#   'address': '124 Lombard St',
#   'latitude': 39.9419748,
#   'longitude': -75.1448595,
#   'stars': 2.5,
#   'price': 'Unknown price',
#   'quality': 'below average quality',
#   'location': 'average location',
#   'service': 'bad service',
#   'safety': 'below average safety'},
#  {'business_id': 'hh6t95hiS-RqRt6bEz1SPw',
#   'name': 'Union League of Philadelphia',
#   'address': '140 S Broad St',
#   'latitude': 39.949988,
#   'longitude': -75.1645963,
#   'stars': 4.0,
#   'price': 'Unknown price',
#   'quality': 'good quality',
#   'location': 'excellent location',
#   'service': 'good service',
#   'safety': 'excellent safety'},
#  {'business_id': 'TZhCpOoo4TIg7dgftWNKyQ',
#   'name': 'W Philadelphia',
#   'address': '1439 Chestnut St',
#   'latitude': 39.9515202,
#   'longitude': -75.1650621,
#   'stars': 3.5,
#   'price': '$$$',
#   'quality': 'good quality',
#   'location': 'good location',
#   'service': 'average service',
#   'safety': 'good safety'},
#  {'business_id': 'lQwSrnzTxhssWHRGyq5rvQ',
#   'name': 'Wyndham Philadelphia Historic District',
#   'address': '400 Arch St',
#   'latitude': 39.9520404,
#   'longitude': -75.147515,
#   'stars': 2.5,
#   'price': '$$',
#   'quality': 'below average quality',
#   'location': 'good location',
#   'service': 'below average service',
#   'safety': 'average safety'}]
