# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import requests
from bs4 import BeautifulSoup
import os

# %%
def scrape_blog(html_links):    
# Set up Chrome options
    options = Options()
    options.add_argument("--disable-extensions")
    options.add_argument("--disable-gpu")

    # Create a new Chrome driver instance
    driver = webdriver.Chrome(options=options)

    # Navigate to the webpage
    driver.get(html_links)

    # Extract the HTML content
    html_content = driver.page_source

    # Close the browser
    driver.quit()

    # Parse the HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    
    for style in soup.find_all('style'):
        style.decompose()

    print(soup.prettify())

# %%
html_links = 'https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/'
scrape_blog(html_links)
# Out:
# <html class="js" lang="en-US" prefix="og: https://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script async="" referrerpolicy="unsafe-url" src="https://de.tynt.com/deb/v2?id=sh!sh&amp;dn=AFSH&amp;cc=1&amp;chpv=14.6.1&amp;chuav=Chromium%3Bv%3D130.0.6723.59%2C%20Google%20Chrome%3Bv%3D130.0.6723.59%2C%20Not%3FA_Brand%3Bv%3D99.0.0.0&amp;chp=macOS&amp;chmob=0&amp;chua=Chromium%3Bv%3D130%2C%20Google%20Chrome%3Bv%3D130%2C%20Not%3FA_Brand%3Bv%3D99&amp;r=&amp;pu=https%3A%2F%2Facupofkims.com%2Fa-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro%2F" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-X2HCN52PYE&amp;cx=c&amp;_slc=1" type="text/javascript">
#   </script>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script async="" src="https://px.owneriq.net/stas/s/igpkg3.js" type="text/javascript">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/308519652912505?v=2.9.173&amp;r=stable&amp;domain=acupofkims.com&amp;hme=ead923021ccd3483ef3b9b04703d0a78b943fbdc01e8d7cec21c5059f1f4a5e9&amp;ex_m=70%2C121%2C107%2C111%2C61%2C4%2C100%2C69%2C16%2C97%2C89%2C51%2C54%2C172%2C175%2C187%2C183%2C184%2C186%2C29%2C101%2C53%2C77%2C185%2C167%2C170%2C180%2C181%2C188%2C131%2C41%2C34%2C143%2C15%2C50%2C194%2C193%2C133%2C18%2C40%2C1%2C43%2C65%2C66%2C67%2C71%2C93%2C17%2C14%2C96%2C92%2C91%2C108%2C52%2C110%2C39%2C109%2C30%2C94%2C26%2C168%2C171%2C140%2C86%2C56%2C84%2C33%2C73%2C0%2C95%2C32%2C28%2C82%2C83%2C88%2C47%2C46%2C87%2C37%2C11%2C12%2C13%2C6%2C7%2C25%2C22%2C23%2C57%2C62%2C64%2C75%2C102%2C27%2C76%2C9%2C8%2C80%2C48%2C21%2C104%2C103%2C105%2C98%2C10%2C20%2C3%2C38%2C74%2C19%2C5%2C90%2C81%2C44%2C35%2C85%2C2%2C36%2C63%2C42%2C106%2C45%2C79%2C68%2C112%2C60%2C59%2C31%2C99%2C58%2C55%2C49%2C78%2C72%2C24%2C113">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-VM820L129D&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="//assets.pinterest.com/js/pinit_main.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.googletagmanager.com/gtm.js?id=GTM-PBN79J&amp;l=dataLayerCBias">
#   </script>
#   <script async="" src="https://assets.flodesk.com/universal.js?v=1729700273717">
#   </script>
#   <script async="" src="https://assets.flodesk.com/universal.js?v=1729700273717">
#   </script>
#   <script data-api-url="https://acupofkims.com/wp-json/wordpress-popular-posts" data-debug="0" data-lang="0" data-post-id="22024" data-sampling="0" data-sampling-rate="100" data-token="7069080ffa" id="wpp-js" src="https://acupofkims.com/wp-content/plugins/wordpress-popular-posts/assets/js/wpp.min.js" type="text/javascript">
#   </script>
#   <!-- Jetpack Site Verification Tags -->
#   <meta content="T02GUs3tILPYZsEwXl4gP3k_4_afQ0l0c52337BY8UA" name="google-site-verification"/>
#   <meta content="d54ae724fb9f6e9d632efda33a67096a" name="p:domain_verify"/>
#   <!-- The SEO Framework by Sybre Waaijer -->
#   <link href="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/" rel="canonical"/>
#   <meta content="So, it’s your first time in Philadelphia and you’re looking for new places to try, but you have no idea where to begin or what to do. Maybe you’ve browsed…" name="description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="A Cup of Kims" property="og:site_name"/>
#   <meta content="A 5-Day Itinerary In Philadelphia From a Local’s Perspective / Ro | A Cup of Kims" property="og:title"/>
#   <meta content="So, it’s your first time in Philadelphia and you’re looking for new places to try, but you have no idea where to begin or what to do. Maybe you’ve browsed YouTube videos from people who have visited…" property="og:description"/>
#   <meta content="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/" property="og:url"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-scaled.jpg" property="og:image"/>
#   <meta content="1707" property="og:image:width"/>
#   <meta content="2560" property="og:image:height"/>
#   <meta content="2024-02-19T18:19:28+00:00" property="article:published_time"/>
#   <meta content="2024-01-29T05:10:26+00:00" property="article:modified_time"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="A 5-Day Itinerary In Philadelphia From a Local’s Perspective / Ro | A Cup of Kims" name="twitter:title"/>
#   <meta content="So, it’s your first time in Philadelphia and you’re looking for new places to try, but you have no idea where to begin or what to do. Maybe you’ve browsed YouTube videos from people who have visited…" name="twitter:description"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-scaled.jpg" name="twitter:image"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://acupofkims.com/#/schema/WebSite","url":"https://acupofkims.com/","name":"A Cup of Kims","description":"A Philadelphia&#x2d;Based Travel &amp; Lifestyle Blog","inLanguage":"en-US","potentialAction":{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://acupofkims.com/search/{search_term_string}/"},"query-input":"required name=search_term_string"},"publisher":{"@type":"Organization","@id":"https://acupofkims.com/#/schema/Organization","name":"A Cup of Kims","url":"https://acupofkims.com/","logo":{"@type":"ImageObject","url":"https://acupofkims.com/wp-content/uploads/2019/07/cropped-acupofkcrest4.png","contentUrl":"https://acupofkims.com/wp-content/uploads/2019/07/cropped-acupofkcrest4.png","width":512,"height":512}}},{"@type":"WebPage","@id":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/","url":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/","name":"A 5&#x2d;Day Itinerary In Philadelphia From a Local&#8217;s Perspective / Ro | A Cup of Kims","description":"So, it&rsquo;s your first time in Philadelphia and you&rsquo;re looking for new places to try, but you have no idea where to begin or what to do. Maybe you&rsquo;ve browsed&#8230;","inLanguage":"en-US","isPartOf":{"@id":"https://acupofkims.com/#/schema/WebSite"},"breadcrumb":{"@type":"BreadcrumbList","@id":"https://acupofkims.com/#/schema/BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":"https://acupofkims.com/","name":"A Cup of Kims"},{"@type":"ListItem","position":2,"item":"https://acupofkims.com/category/uncategorized/","name":"Category: Uncategorized"},{"@type":"ListItem","position":3,"name":"A 5&#x2d;Day Itinerary In Philadelphia From a Local&#8217;s Perspective / Ro"}]},"potentialAction":{"@type":"ReadAction","target":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/"},"datePublished":"2024-02-19T18:19:28+00:00","dateModified":"2024-01-29T05:10:26+00:00","author":{"@type":"Person","@id":"https://acupofkims.com/#/schema/Person/91e550e70652870e2895e4c8f331b005","name":"Ro","description":"Writer at A Cup of Kims..."}}]}
#   </script>
#   <!-- / The SEO Framework by Sybre Waaijer | 9.68ms meta | 1.58ms boot -->
#   <!-- Search Engine Optimization by Rank Math - https://rankmath.com/ -->
#   <title>
#    A 5-Day Itinerary In Philadelphia From a Local’s Perspective / Ro | A Cup of Kims
#   </title>
#   <meta content="So, it's your first time in Philadelphia and you're looking for new places to try, but you don't what to do. Here's Our 5-Day Itinerary in Philadelphia!" name="description"/>
#   <meta content="index, follow, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots"/>
#   <link href="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="A 5-Day Itinerary In Philadelphia From a Local's Perspective / Ro - A Cup of Kims" property="og:title"/>
#   <meta content="So, it's your first time in Philadelphia and you're looking for new places to try, but you don't what to do. Here's Our 5-Day Itinerary in Philadelphia!" property="og:description"/>
#   <meta content="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/" property="og:url"/>
#   <meta content="A Cup of Kims" property="og:site_name"/>
#   <meta content="5-day itinerary philadelphia" property="article:tag"/>
#   <meta content="philadelphia" property="article:tag"/>
#   <meta content="travel" property="article:tag"/>
#   <meta content="traveling" property="article:tag"/>
#   <meta content="Traveling on a Budget" property="article:section"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-683x1024.jpg" property="og:image"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-683x1024.jpg" property="og:image:secure_url"/>
#   <meta content="683" property="og:image:width"/>
#   <meta content="1024" property="og:image:height"/>
#   <meta content="itinerary in philadelphia" property="og:image:alt"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="2024-02-19T18:19:28+00:00" property="article:published_time"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="A 5-Day Itinerary In Philadelphia From a Local's Perspective / Ro - A Cup of Kims" name="twitter:title"/>
#   <meta content="So, it's your first time in Philadelphia and you're looking for new places to try, but you don't what to do. Here's Our 5-Day Itinerary in Philadelphia!" name="twitter:description"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-683x1024.jpg" name="twitter:image"/>
#   <meta content="Written by" name="twitter:label1"/>
#   <meta content="Ro" name="twitter:data1"/>
#   <meta content="Time to read" name="twitter:label2"/>
#   <meta content="4 minutes" name="twitter:data2"/>
#   <script class="rank-math-schema" type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":["Organization","Person"],"@id":"https://acupofkims.com/#person","name":"Ro","url":"https://acupofkims.com","logo":{"@type":"ImageObject","@id":"https://acupofkims.com/#logo","url":"https://acupofkims.com/wp-content/uploads/2019/07/acupofkcrest4.png","contentUrl":"https://acupofkims.com/wp-content/uploads/2019/07/acupofkcrest4.png","caption":"Ro","inLanguage":"en-US","width":"2100","height":"1500"},"image":{"@id":"https://acupofkims.com/#logo"}},{"@type":"WebSite","@id":"https://acupofkims.com/#website","url":"https://acupofkims.com","name":"Ro","publisher":{"@id":"https://acupofkims.com/#person"},"inLanguage":"en-US"},{"@type":"ImageObject","@id":"https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-scaled.jpg","url":"https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-scaled.jpg","width":"1707","height":"2560","inLanguage":"en-US"},{"@type":"WebPage","@id":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/#webpage","url":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/","name":"A 5-Day Itinerary In Philadelphia From a Local&#039;s Perspective / Ro - A Cup of Kims","datePublished":"2024-02-19T18:19:28+00:00","dateModified":"2024-02-19T18:19:28+00:00","isPartOf":{"@id":"https://acupofkims.com/#website"},"primaryImageOfPage":{"@id":"https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-scaled.jpg"},"inLanguage":"en-US"},{"@type":"Person","@id":"https://acupofkims.com/author/admin/","name":"Ro","url":"https://acupofkims.com/author/admin/","image":{"@type":"ImageObject","@id":"https://secure.gravatar.com/avatar/575721984c2b3c2268ca17d8038d30eb?s=96&amp;d=mm&amp;r=g","url":"https://secure.gravatar.com/avatar/575721984c2b3c2268ca17d8038d30eb?s=96&amp;d=mm&amp;r=g","caption":"Ro","inLanguage":"en-US"}},{"@type":"BlogPosting","headline":"A 5-Day Itinerary In Philadelphia From a Local&#039;s Perspective / Ro - A Cup of Kims","keywords":"itinerary in philadelphia","datePublished":"2024-02-19T18:19:28+00:00","dateModified":"2024-02-19T18:19:28+00:00","articleSection":"According to Kims, According to The Kims, Delaware Valley, Pennsylvania, Philadelphia, Travel, Traveling on a Budget, Uncategorized","author":{"@id":"https://acupofkims.com/author/admin/","name":"Ro"},"publisher":{"@id":"https://acupofkims.com/#person"},"description":"So, it&#039;s your first time in Philadelphia and you&#039;re looking for new places to try, but you don&#039;t what to do. Here&#039;s Our 5-Day Itinerary in Philadelphia!","name":"A 5-Day Itinerary In Philadelphia From a Local&#039;s Perspective / Ro - A Cup of Kims","@id":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/#richSnippet","isPartOf":{"@id":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/#webpage"},"image":{"@id":"https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-scaled.jpg"},"inLanguage":"en-US","mainEntityOfPage":{"@id":"https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/#webpage"}}]}
#   </script>
#   <!-- /Rank Math WordPress SEO plugin -->
#   <link href="//secure.gravatar.com" rel="dns-prefetch"/>
#   <link href="//stats.wp.com" rel="dns-prefetch"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//code.ionicframework.com" rel="dns-prefetch"/>
#   <link href="//cdn.openshareweb.com" rel="dns-prefetch"/>
#   <link href="//cdn.shareaholic.net" rel="dns-prefetch"/>
#   <link href="//www.shareaholic.net" rel="dns-prefetch"/>
#   <link href="//analytics.shareaholic.com" rel="dns-prefetch"/>
#   <link href="//recs.shareaholic.com" rel="dns-prefetch"/>
#   <link href="//partner.shareaholic.com" rel="dns-prefetch"/>
#   <link href="//v0.wordpress.com" rel="dns-prefetch"/>
#   <link href="//c0.wp.com" rel="dns-prefetch"/>
#   <link href="https://acupofkims.com/feed/" rel="alternate" title="A Cup of Kims » Feed" type="application/rss+xml"/>
#   <link href="https://acupofkims.com/comments/feed/" rel="alternate" title="A Cup of Kims » Comments Feed" type="application/rss+xml"/>
#   <link href="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/feed/" rel="alternate" title="A Cup of Kims » A 5-Day Itinerary In Philadelphia From a Local’s Perspective / Ro Comments Feed" type="application/rss+xml"/>
#   <!-- Shareaholic - https://www.shareaholic.com -->
#   <link as="script" href="//cdn.shareaholic.net/assets/pub/shareaholic.js" rel="preload"/>
#   <script data-cfasync="false" data-no-minify="1">
#    _SHR_SETTINGS = {"endpoints":{"local_recs_url":"https:\/\/acupofkims.com\/wp-admin\/admin-ajax.php?action=shareaholic_permalink_related","ajax_url":"https:\/\/acupofkims.com\/wp-admin\/admin-ajax.php"},"site_id":"8da01fda899c850a74073290371e6117","url_components":{"year":"2024","monthnum":"02","day":"19","hour":"18","minute":"19","second":"28","post_id":"22024","postname":"a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro","category":"uncategorized"}};
#   </script>
#   <!-- Shareaholic Content Tags -->
#   <meta content="A Cup of Kims" name="shareaholic:site_name"/>
#   <meta content="en-US" name="shareaholic:language"/>
#   <meta content="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/" name="shareaholic:url"/>
#   <meta content="tag:5-day itinerary philadelphia, tag:philadelphia, tag:travel, tag:traveling, cat:traveling on a budget, cat:according to kims, cat:according to the kims, cat:delaware valley, cat:pennsylvania, cat:philadelphia, cat:travel, type:post" name="shareaholic:keywords"/>
#   <meta content="2024-02-19T18:19:28+00:00" name="shareaholic:article_published_time"/>
#   <meta content="2024-01-29T05:10:26+00:00" name="shareaholic:article_modified_time"/>
#   <meta content="true" name="shareaholic:shareable_page"/>
#   <meta content="Ro" name="shareaholic:article_author_name"/>
#   <meta content="8da01fda899c850a74073290371e6117" name="shareaholic:site_id"/>
#   <meta content="9.7.12" name="shareaholic:wp_version"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-6-640x960.jpg" name="shareaholic:image"/>
#   <!-- Shareaholic Content Tags End -->
#   <script type="text/javascript">
#    /* <![CDATA[ */
# window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/15.0.3\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/15.0.3\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/acupofkims.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.6.2"}};
# /*! This file is auto-generated */
# !function(i,n){var o,s,e;function c(e){try{var t={supportTests:e,timestamp:(new Date).valueOf()};sessionStorage.setItem(o,JSON.stringify(t))}catch(e){}}function p(e,t,n){e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(t,0,0);var t=new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data),r=(e.clearRect(0,0,e.canvas.width,e.canvas.height),e.fillText(n,0,0),new Uint32Array(e.getImageData(0,0,e.canvas.width,e.canvas.height).data));return t.every(function(e,t){return e===r[t]})}function u(e,t,n){switch(t){case"flag":return n(e,"\ud83c\udff3\ufe0f\u200d\u26a7\ufe0f","\ud83c\udff3\ufe0f\u200b\u26a7\ufe0f")?!1:!n(e,"\ud83c\uddfa\ud83c\uddf3","\ud83c\uddfa\u200b\ud83c\uddf3")&&!n(e,"\ud83c\udff4\udb40\udc67\udb40\udc62\udb40\udc65\udb40\udc6e\udb40\udc67\udb40\udc7f","\ud83c\udff4\u200b\udb40\udc67\u200b\udb40\udc62\u200b\udb40\udc65\u200b\udb40\udc6e\u200b\udb40\udc67\u200b\udb40\udc7f");case"emoji":return!n(e,"\ud83d\udc26\u200d\u2b1b","\ud83d\udc26\u200b\u2b1b")}return!1}function f(e,t,n){var r="undefined"!=typeof WorkerGlobalScope&&self instanceof WorkerGlobalScope?new OffscreenCanvas(300,150):i.createElement("canvas"),a=r.getContext("2d",{willReadFrequently:!0}),o=(a.textBaseline="top",a.font="600 32px Arial",{});return e.forEach(function(e){o[e]=t(a,e,n)}),o}function t(e){var t=i.createElement("script");t.src=e,t.defer=!0,i.head.appendChild(t)}"undefined"!=typeof Promise&&(o="wpEmojiSettingsSupports",s=["flag","emoji"],n.supports={everything:!0,everythingExceptFlag:!0},e=new Promise(function(e){i.addEventListener("DOMContentLoaded",e,{once:!0})}),new Promise(function(t){var n=function(){try{var e=JSON.parse(sessionStorage.getItem(o));if("object"==typeof e&&"number"==typeof e.timestamp&&(new Date).valueOf()<e.timestamp+604800&&"object"==typeof e.supportTests)return e.supportTests}catch(e){}return null}();if(!n){if("undefined"!=typeof Worker&&"undefined"!=typeof OffscreenCanvas&&"undefined"!=typeof URL&&URL.createObjectURL&&"undefined"!=typeof Blob)try{var e="postMessage("+f.toString()+"("+[JSON.stringify(s),u.toString(),p.toString()].join(",")+"));",r=new Blob([e],{type:"text/javascript"}),a=new Worker(URL.createObjectURL(r),{name:"wpTestEmojiSupports"});return void(a.onmessage=function(e){c(n=e.data),a.terminate(),t(n)})}catch(e){}c(n=f(s,u,p))}t(n)}).then(function(e){for(var t in e)n.supports[t]=e[t],n.supports.everything=n.supports.everything&&n.supports[t],"flag"!==t&&(n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&n.supports[t]);n.supports.everythingExceptFlag=n.supports.everythingExceptFlag&&!n.supports.flag,n.DOMReady=!1,n.readyCallback=function(){n.DOMReady=!0}}).then(function(){return e}).then(function(){var e;n.supports.everything||(n.readyCallback(),(e=n.source||{}).concatemoji?t(e.concatemoji):e.wpemoji&&e.twemoji&&(t(e.twemoji),t(e.wpemoji)))}))}((window,document),window._wpemojiSettings);
# /* ]]> */
#   </script>
#   <link href="https://acupofkims.com/wp-content/plugins/instagram-feed/css/sbi-styles.min.css?ver=6.5.0" id="sbi_styles-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/genesis-simple-share/assets/css/share.min.css?ver=0.1.0" id="genesis-simple-share-plugin-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/genesis-simple-share/assets/css/genericons.min.css?ver=0.1.0" id="genesis-simple-share-genericons-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/themes/hello_co/style.css?ver=1.0.0" id="hello-co-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/c/6.6.2/wp-includes/css/dist/block-library/style.min.css" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/c/6.6.2/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css" id="mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/c/6.6.2/wp-includes/js/mediaelement/wp-mediaelement.min.css" id="wp-mediaelement-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/cresta-posts-box/css/cresta-posts-box-style.min.css?ver=1.3.5" id="cresta-posts-box-style-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/organic-customizer-widgets/public/css/organic-widgets-public.css?ver=1.4.17" id="organic-widgets-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/responsive-header-image-slider/css/responsiveimgslider.css?ver=3.2.1" id="respslidercss-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/wordpress-popular-posts/assets/css/wpp.css?ver=7.0.1" id="wordpress-popular-posts-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Montserrat%3A400%2C700%7CMuli%7CPoppins&amp;ver=6.6.2" id="hyd-google-fonts-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//code.ionicframework.com/ionicons/2.0.1/css/ionicons.min.css?ver=6.6.2" id="ionicons-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/c/6.6.2/wp-includes/css/dashicons.min.css" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/themes/hello_co/lib/gutenberg/front-end.css?ver=1.0.0" id="hyd-gutenberg-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/organic-customizer-widgets/public/css/font-awesome.css?ver=6.6.2" id="organic-widgets-fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/simple-social-icons/css/style.css?ver=3.0.2" id="simple-social-icons-font-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://acupofkims.com/wp-content/plugins/gdpr-cookie-compliance/dist/styles/gdpr-main.css?ver=4.15.2" id="moove_gdpr_frontend-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://c0.wp.com/p/jetpack/13.8.2/css/jetpack.css" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
#   <script id="jetpack_related-posts-js-extra" type="text/javascript">
#    /* <![CDATA[ */
# var related_posts_js_options = {"post_heading":"h4"};
# /* ]]> */
#   </script>
#   <script id="jetpack_related-posts-js" src="https://c0.wp.com/p/jetpack/13.8.2/_inc/build/related-posts/related-posts.min.js" type="text/javascript">
#   </script>
#   <script id="jquery-core-js" src="https://c0.wp.com/c/6.6.2/wp-includes/js/jquery/jquery.min.js" type="text/javascript">
#   </script>
#   <script id="jquery-migrate-js" src="https://c0.wp.com/c/6.6.2/wp-includes/js/jquery/jquery-migrate.min.js" type="text/javascript">
#   </script>
#   <script id="genesis-simple-share-plugin-js-js" src="https://acupofkims.com/wp-content/plugins/genesis-simple-share/assets/js/sharrre/jquery.sharrre.min.js?ver=0.1.0" type="text/javascript">
#   </script>
#   <script id="genesis-simple-share-waypoint-js-js" src="https://acupofkims.com/wp-content/plugins/genesis-simple-share/assets/js/waypoints.min.js?ver=0.1.0" type="text/javascript">
#   </script>
#   <script id="organic-widgets-js" src="https://acupofkims.com/wp-content/plugins/organic-customizer-widgets/public/js/organic-widgets-public.js?ver=1.4.17" type="text/javascript">
#   </script>
#   <script id="respsliderjs-js" src="https://acupofkims.com/wp-content/plugins/responsive-header-image-slider/js/jquery.slides.min.js?ver=3.2.1" type="text/javascript">
#   </script>
#   <script id="organic-widgets-backgroundimagebrightness-js-js" src="https://acupofkims.com/wp-content/plugins/organic-customizer-widgets/public/js/jquery.backgroundbrightness.js?ver=6.6.2" type="text/javascript">
#   </script>
#   <link href="https://acupofkims.com/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://acupofkims.com/wp-json/wp/v2/posts/22024" rel="alternate" title="JSON" type="application/json"/>
#   <link href="https://acupofkims.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="https://acupofkims.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Facupofkims.com%2Fa-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
#   <link href="https://acupofkims.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Facupofkims.com%2Fa-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro%2F&amp;format=xml" rel="alternate" title="oEmbed (XML)" type="text/xml+oembed"/>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace('no-js', 'js');
#   </script>
#   <link href="https://acupofkims.com/xmlrpc.php" rel="pingback"/>
#   <meta content="8c2b37d6e4675d5a2e858f6200696f50" name="p:domain_verify"/>
#   <script async="" src="https://a-cup-of-kims.disqus.com/count.js" type="text/javascript">
#   </script>
#   <script async="" src="https://a-cup-of-kims.disqus.com/embed.js" type="text/javascript">
#   </script>
#   <script src="//a-cup-of-kims.disqus.com/count-data.js?1=22024%20https%3A%2F%2Facupofkims.com%2F%3Fp%3D22024">
#   </script>
#   <script async="" id="dsq_recs_scr" src="https://a-cup-of-kims.disqus.com/recommendations.js">
#   </script>
#   <script async="" charset="UTF-8" src="https://c.disquscdn.com/next/embed/alfie_v4.63f1ab6d6b9d5807dc0c94ef3fe0b851.js">
#   </script>
#  </head>
#  <body class="post-template-default single single-post postid-22024 single-format-standard custom-background wp-embed-responsive custom-header header-image content-sidebar genesis-breadcrumbs-hidden genesis-footer-widgets-hidden" data-ff-5d782884cb4d50000f51084c-rendered="" data-pin-hover="true" itemscope="" itemtype="https://schema.org/WebPage" style="zoom: 1;">
#   <br/>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-146792027-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-146792027-1');
#   </script>
#   <link href="https://acupofkims.com/wp-content/uploads/2019/07/cropped-acupofkcrest4-32x32.png" rel="icon" sizes="32x32"/>
#   <link href="https://acupofkims.com/wp-content/uploads/2019/07/cropped-acupofkcrest4-192x192.png" rel="icon" sizes="192x192"/>
#   <link href="https://acupofkims.com/wp-content/uploads/2019/07/cropped-acupofkcrest4-180x180.png" rel="apple-touch-icon"/>
#   <meta content="https://acupofkims.com/wp-content/uploads/2019/07/cropped-acupofkcrest4-270x270.png" name="msapplication-TileImage"/>
#   <a class="to-top" href="#0" title="Back To Top">
#    Top
#   </a>
#   <div class="site-container">
#    <div class="sticky-social widget-area">
#     <section class="widget simple-social-icons" id="simple-social-icons-4">
#      <div class="widget-wrap">
#       <ul class="alignleft">
#        <li class="ssi-facebook">
#         <a href="https://www.facebook.com/acupofkims" rel="noopener noreferrer" target="_blank">
#          <svg aria-labelledby="social-facebook-4" class="social-facebook" role="img">
#           <title id="social-facebook-4">
#            Facebook
#           </title>
#           <use xlink:href="https://acupofkims.com/wp-content/plugins/simple-social-icons/symbol-defs.svg#social-facebook">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="ssi-instagram">
#         <a href="https://www.instagram.com/acupofkims" rel="noopener noreferrer" target="_blank">
#          <svg aria-labelledby="social-instagram-4" class="social-instagram" role="img">
#           <title id="social-instagram-4">
#            Instagram
#           </title>
#           <use xlink:href="https://acupofkims.com/wp-content/plugins/simple-social-icons/symbol-defs.svg#social-instagram">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="ssi-pinterest">
#         <a href="https://www.pinterest.com/acupofkims/" rel="noopener noreferrer" target="_blank">
#          <svg aria-labelledby="social-pinterest-4" class="social-pinterest" role="img">
#           <title id="social-pinterest-4">
#            Pinterest
#           </title>
#           <use xlink:href="https://acupofkims.com/wp-content/plugins/simple-social-icons/symbol-defs.svg#social-pinterest">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="ssi-tumblr">
#         <a href="https://acupofkims.tumblr.com" rel="noopener noreferrer" target="_blank">
#          <svg aria-labelledby="social-tumblr-4" class="social-tumblr" role="img">
#           <title id="social-tumblr-4">
#            Tumblr
#           </title>
#           <use xlink:href="https://acupofkims.com/wp-content/plugins/simple-social-icons/symbol-defs.svg#social-tumblr">
#           </use>
#          </svg>
#         </a>
#        </li>
#        <li class="ssi-twitter">
#         <a href="https://www.twitter.com/acupofkims" rel="noopener noreferrer" target="_blank">
#          <svg aria-labelledby="social-twitter-4" class="social-twitter" role="img">
#           <title id="social-twitter-4">
#            Twitter
#           </title>
#           <use xlink:href="https://acupofkims.com/wp-content/plugins/simple-social-icons/symbol-defs.svg#social-twitter">
#           </use>
#          </svg>
#         </a>
#        </li>
#       </ul>
#      </div>
#     </section>
#    </div>
#    <header class="site-header" itemscope="" itemtype="https://schema.org/WPHeader">
#     <div class="wrap">
#      <div class="title-area">
#       <p class="site-title" itemprop="headline">
#        <a href="https://acupofkims.com/">
#         A Cup of Kims
#        </a>
#       </p>
#      </div>
#      <div class="widget-area header-widget-area">
#       <section class="widget widget_nav_menu" id="nav_menu-12">
#        <div class="widget-wrap">
#        </div>
#       </section>
#      </div>
#     </div>
#    </header>
#    <button aria-expanded="false" aria-pressed="false" class="menu-toggle dashicons-before dashicons-menu" id="genesis-mobile-nav-secondary" role="button">
#     Menu
#    </button>
#    <nav aria-label="Secondary" class="nav-secondary genesis-responsive-menu" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
#     <div class="wrap">
#      <ul class="menu genesis-nav-menu menu-secondary" id="menu-blog-links">
#       <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-16235" id="menu-item-16235">
#        <a href="https://acupofkims.com/" itemprop="url">
#         <span class="sub">
#         </span>
#         <span itemprop="name">
#          Home
#         </span>
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16223" id="menu-item-16223">
#        <a href="https://acupofkims.com/blog/" itemprop="url">
#         <span itemprop="name">
#          Blog
#         </span>
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-16219" id="menu-item-16219">
#        <a href="https://acupofkims.com/about/" itemprop="url">
#         <span itemprop="name">
#          About
#         </span>
#        </a>
#        <button aria-expanded="false" aria-pressed="false" class="sub-menu-toggle dashicons-before dashicons-arrow-down-alt2" role="button">
#         <span class="screen-reader-text">
#          Submenu
#         </span>
#        </button>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16217" id="menu-item-16217">
#          <a href="https://acupofkims.com/what-is-this-blog-about/" itemprop="url">
#           <span itemprop="name">
#            What Is This Blog About?
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18115" id="menu-item-18115">
#          <a href="https://acupofkims.com/where-we-have-traveled-to/" itemprop="url">
#           <span class="sub">
#           </span>
#           <span itemprop="name">
#            Our Travels
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20771" id="menu-item-20771">
#          <a href="https://acupofkims.com/f-a-q/" itemprop="url">
#           <span itemprop="name">
#            F.A.Q
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20987" id="menu-item-20987">
#          <a href="https://acupofkims.com/about/contact/" itemprop="url">
#           <span itemprop="name">
#            Contact
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16234" id="menu-item-16234">
#          <a href="https://acupofkims.com/contact/" itemprop="url">
#           <span itemprop="name">
#            Work With Us
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-21573" id="menu-item-21573">
#          <a href="https://acupofkims.com/the-brew-a-list-of-goals-in-3-years/" itemprop="url">
#           <span class="sub">
#           </span>
#           <span itemprop="name">
#            The Brew List in 3 Years
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-privacy-policy menu-item-16216" id="menu-item-16216">
#          <a href="https://acupofkims.com/about/privacy-policy/" itemprop="url" rel="privacy-policy">
#           <span itemprop="name">
#            Privacy Policy
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16232" id="menu-item-16232">
#          <a href="https://acupofkims.com/about/cookie-policy/" itemprop="url">
#           <span itemprop="name">
#            Cookie Policy
#           </span>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-16218" id="menu-item-16218">
#        <a href="https://acupofkims.com/freshly-brewed-newsletter/" itemprop="url">
#         <span itemprop="name">
#          Freshly Brewed
#         </span>
#        </a>
#        <button aria-expanded="false" aria-pressed="false" class="sub-menu-toggle dashicons-before dashicons-arrow-down-alt2" role="button">
#         <span class="screen-reader-text">
#          Submenu
#         </span>
#        </button>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16214" id="menu-item-16214">
#          <a href="https://acupofkims.com/e-guides/" itemprop="url">
#           <span itemprop="name">
#            E-Guides
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-16215" id="menu-item-16215">
#          <a href="https://acupofkims.com/presets-for-all-lightroom-presets-for-darker-skin-tones/" itemprop="url">
#           <span class="sub">
#           </span>
#           <span itemprop="name">
#            Presets
#           </span>
#          </a>
#          <button aria-expanded="false" aria-pressed="false" class="sub-menu-toggle dashicons-before dashicons-arrow-down-alt2" role="button">
#           <span class="screen-reader-text">
#            Submenu
#           </span>
#          </button>
#          <ul class="sub-menu">
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20214" id="menu-item-20214">
#            <a href="https://acupofkims.com/subscribe-to-get-our-presets/" itemprop="url">
#             <span itemprop="name">
#              Subscribe to Get Our Presets!
#             </span>
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18430" id="menu-item-18430">
#            <a href="https://acupofkims.com/free-warm-lightroom-mobile-presets-for-darker-skin-tones/" itemprop="url">
#             <span itemprop="name">
#              FREE Warm Lightroom Mobile Presets for Darker Skin Tones
#             </span>
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-18431" id="menu-item-18431">
#            <a href="https://acupofkims.com/presets-for-all-lightroom-presets-for-darker-skin-tones/" itemprop="url">
#             <span itemprop="name">
#              Presets for All: Lightroom Presets for Darker Skin Tones
#             </span>
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-16212" id="menu-item-16212">
#        <a href="https://acupofkims.com/resources/" itemprop="url">
#         <span itemprop="name">
#          Resources
#         </span>
#        </a>
#        <button aria-expanded="false" aria-pressed="false" class="sub-menu-toggle dashicons-before dashicons-arrow-down-alt2" role="button">
#         <span class="screen-reader-text">
#          Submenu
#         </span>
#        </button>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21051" id="menu-item-21051">
#          <a href="https://acupofkims.com/photography/" itemprop="url">
#           <span class="sub">
#           </span>
#           <span itemprop="name">
#            Photography Editing &amp; Presets
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20561" id="menu-item-20561">
#          <a href="https://acupofkims.com/coffee/" itemprop="url">
#           <span itemprop="name">
#            Coffee Guide
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21833" id="menu-item-21833">
#          <a href="https://acupofkims.com/budget-friendly-new-england-travel-guide/" itemprop="url">
#           <span itemprop="name">
#            Budget-Friendly New England Travel Guide
#           </span>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16225" id="menu-item-16225">
#        <a href="https://acupofkims.com/category-index/" itemprop="url">
#         <span class="sub">
#         </span>
#         <span itemprop="name">
#          Categories
#         </span>
#        </a>
#       </li>
#       <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu-item-16227" id="menu-item-16227">
#        <a href="https://acupofkims.com/shop/" itemprop="url">
#         <span itemprop="name">
#          Shop
#         </span>
#        </a>
#        <button aria-expanded="false" aria-pressed="false" class="sub-menu-toggle dashicons-before dashicons-arrow-down-alt2" role="button">
#         <span class="screen-reader-text">
#          Submenu
#         </span>
#        </button>
#        <ul class="sub-menu">
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16229" id="menu-item-16229">
#          <a href="https://acupofkims.com/shop/home-decor/" itemprop="url">
#           <span itemprop="name">
#            Home Decor
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-22319" id="menu-item-22319">
#          <a href="https://acupofkims.com/shop/amazon-finds/" itemprop="url">
#           <span itemprop="name">
#            Amazon Finds
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16231" id="menu-item-16231">
#          <a href="https://acupofkims.com/shop/travel/" itemprop="url">
#           <span itemprop="name">
#            Travel
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-16228" id="menu-item-16228">
#          <a href="https://acupofkims.com/shop/fashion/" itemprop="url">
#           <span itemprop="name">
#            Fashion
#           </span>
#          </a>
#         </li>
#         <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20448" id="menu-item-20448">
#          <a href="https://acupofkims.com/holiday-shop/" itemprop="url">
#           <span itemprop="name">
#            Holiday Shop
#           </span>
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-17079" id="menu-item-17079">
#        <a href="https://www.etsy.com/shop/ACupofKims" itemprop="url">
#         <span class="sub">
#         </span>
#         <span itemprop="name">
#          Preset Shop
#         </span>
#        </a>
#       </li>
#       <li class="fall a background-color 731A07 color ffffff menu-item menu-item-type-post_type menu-item-object-page menu-item-22478" id="menu-item-22478">
#        <a href="https://acupofkims.com/fun-fall-activities-and-ideas/" itemprop="url">
#         <span class="sub">
#         </span>
#         <span itemprop="name">
#          Fall
#         </span>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <div class="site-inner">
#     <div class="content-sidebar-wrap">
#      <main class="content">
#       <article aria-label="A 5-Day Itinerary In Philadelphia From a Local’s Perspective / Ro" class="post-22024 post type-post status-publish format-standard has-post-thumbnail category-traveling-on-a-budget category-according-to-kims category-according-to-the-kims category-delaware-valley category-pennsylvania category-philadelphia category-travel category-uncategorized tag-5-day-itinerary-philadelphia tag-philadelphia tag-travel tag-traveling entry" itemscope="" itemtype="https://schema.org/CreativeWork">
#        <header class="entry-header">
#         <h1 class="entry-title" itemprop="headline">
#          A 5-Day Itinerary In Philadelphia From a Local’s Perspective / Ro
#         </h1>
#         <p class="entry-meta">
#          <time class="entry-time" datetime="2024-02-19T18:19:28+00:00" itemprop="datePublished">
#           February 19, 2024
#          </time>
#          by
#          <span class="entry-author" itemprop="author" itemscope="" itemtype="https://schema.org/Person">
#           <a class="entry-author-link" href="https://acupofkims.com/author/admin/" itemprop="url" rel="author">
#            <span class="entry-author-name" itemprop="name">
#             Ro
#            </span>
#           </a>
#          </span>
#          <span class="entry-comments-link">
#           <a data-disqus-identifier="22024 https://acupofkims.com/?p=22024" href="https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/#disqus_thread">
#            2 Comments
#           </a>
#          </span>
#         </p>
#        </header>
#        <div class="entry-content" itemprop="text">
#         <figure class="wp-block-image alignfull size-large">
#          <img alt="" class="wp-image-15341 lazyloaded" data-sizes="(max-width: 683px) 100vw, 683px" data-src="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-683x1024.jpg" data-srcset="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-683x1024.jpg 683w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-600x900.jpg 600w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-200x300.jpg 200w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-768x1152.jpg 768w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-800x1200.jpg 800w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-640x960.jpg 640w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-560x840.jpg 560w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-scaled.jpg 1707w" decoding="async" height="1024" sizes="(max-width: 683px) 100vw, 683px" src="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-683x1024.jpg" srcset="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-683x1024.jpg 683w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-600x900.jpg 600w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-200x300.jpg 200w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-768x1152.jpg 768w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-800x1200.jpg 800w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-640x960.jpg 640w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-560x840.jpg 560w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-scaled.jpg 1707w" style="--smush-placeholder-width: 683px; --smush-placeholder-aspect-ratio: 683/1024;" width="683"/>
#          <noscript>
#           <img alt="" class="wp-image-15341" decoding="async" height="1024" sizes="(max-width: 683px) 100vw, 683px" src="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-683x1024.jpg" srcset="https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-683x1024.jpg 683w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-600x900.jpg 600w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-200x300.jpg 200w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-768x1152.jpg 768w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-800x1200.jpg 800w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-640x960.jpg 640w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-560x840.jpg 560w, https://acupofkims.com/wp-content/uploads/2019/09/oldcityphiladelphia-1-7-scaled.jpg 1707w" width="683"/>
#          </noscript>
#         </figure>
#         <p class="has-drop-cap">
#          <strong>
#           S
#          </strong>
#          o, it’s your first time in Philadelphia and you’re looking for new places to try, but you have no idea where to begin or what to do. Maybe you’ve browsed YouTube videos from people who have visited these places, but you’re hoping to hear from a local’s perspective, what they’d recommend visiting and what things they’d recommend skipping. Well, my husband came up with the idea of writing a post just for that purpose – to help people who have never been to the city before find some pretty cool spots and plan their visits here, based on what we think would be an ideal trip. We each came up with our own personal itineraries and will be sharing those with you in two separate posts.
#         </p>
#         <p>
# ...
#       </li>
#      </ul>
#      <div class="moove-gdpr-branding-cnt">
#       <a class="moove-gdpr-branding" href="https://wordpress.org/plugins/gdpr-cookie-compliance/" rel="noopener noreferrer" target="_blank">
#        Powered by
#        <span>
#         GDPR Cookie Compliance
#        </span>
#       </a>
#      </div>
#      <!--  .moove-gdpr-branding -->
#     </div>
#     <!--  .moove-gdpr-modal-left-content -->
#     <div class="moove-gdpr-modal-right-content">
#      <div class="moove-gdpr-modal-title">
#      </div>
#      <!-- .moove-gdpr-modal-ritle -->
#      <div class="main-modal-content">
#       <div class="moove-gdpr-tab-content">
#        <div class="moove-gdpr-tab-main" id="privacy_overview">
#         <span class="tab-title">
#          Privacy Overview
#         </span>
#         <div class="moove-gdpr-tab-main-content">
#          <p>
#           This website uses cookies so that we can provide you with the best user experience possible. Cookie information is stored in your browser and performs functions such as recognizing you when you return to our website and helping our team to understand which sections of the website you find most interesting and useful. You can read more about our cookie policy
#           <strong>
#            <a href="https://acupofkims.com/about/cookie-policy/" target="_blank">
#             here
#            </a>
#           </strong>
#           and our privacy policy
#           <strong>
#            <a href="https://acupofkims.com/about/privacy-policy/" target="_blank">
#             here
#            </a>
#           </strong>
#           .
#          </p>
#         </div>
#         <!--  .moove-gdpr-tab-main-content -->
#        </div>
#        <!-- #privacy_overview -->
#        <div class="moove-gdpr-tab-main" id="strict-necessary-cookies" style="display:none">
#         <span class="tab-title">
#          Strictly Necessary Cookies
#         </span>
#         <div class="moove-gdpr-tab-main-content">
#          <p>
#           Strictly Necessary Cookie should be enabled at all times so that we can save your preferences for cookie settings.
#          </p>
#          <div class="moove-gdpr-status-bar">
#           <div class="gdpr-cc-form-wrap">
#            <div class="gdpr-cc-form-fieldset">
#             <label class="cookie-switch" for="moove_gdpr_strict_cookies">
#              <span class="gdpr-sr-only">
#               Enable or Disable Cookies
#              </span>
#              <input aria-label="Strictly Necessary Cookies" id="moove_gdpr_strict_cookies" name="moove_gdpr_strict_cookies" type="checkbox" value="check"/>
#              <span class="cookie-slider cookie-round" data-text-disabled="Disabled" data-text-enable="Enabled">
#              </span>
#             </label>
#            </div>
#            <!-- .gdpr-cc-form-fieldset -->
#           </div>
#           <!-- .gdpr-cc-form-wrap -->
#          </div>
#          <!-- .moove-gdpr-status-bar -->
#          <div class="moove-gdpr-strict-warning-message" style="margin-top: 10px;">
#           <p>
#            If you disable this cookie, we will not be able to save your preferences. This means that every time you visit this website you will need to enable or disable cookies again.
#           </p>
#          </div>
#          <!--  .moove-gdpr-tab-main-content -->
#         </div>
#         <!--  .moove-gdpr-tab-main-content -->
#        </div>
#        <!-- #strict-necesarry-cookies -->
#        <div class="moove-gdpr-tab-main" id="cookie_policy_modal" style="display:none">
#         <span class="tab-title">
#          Cookie Policy
#         </span>
#         <div class="moove-gdpr-tab-main-content">
#          <p>
#           More information about our
#           <a href="https://acupofkims.com/about/cookie-policy/" target="_blank">
#            Cookie Policy
#           </a>
#          </p>
#         </div>
#         <!--  .moove-gdpr-tab-main-content -->
#        </div>
#       </div>
#       <!--  .moove-gdpr-tab-content -->
#      </div>
#      <!--  .main-modal-content -->
#      <div class="moove-gdpr-modal-footer-content">
#       <div class="moove-gdpr-button-holder">
#        <button aria-label="Enable All" class="mgbutton moove-gdpr-modal-allow-all button-visible">
#         Enable All
#        </button>
#        <button aria-label="Save Settings" class="mgbutton moove-gdpr-modal-save-settings button-visible">
#         Save Settings
#        </button>
#       </div>
#       <!--  .moove-gdpr-button-holder -->
#      </div>
#      <!--  .moove-gdpr-modal-footer-content -->
#     </div>
#     <!--  .moove-gdpr-modal-right-content -->
#     <div class="moove-clearfix">
#     </div>
#    </div>
#    <!--  .moove-gdpr-modal-content -->
#   </div>
#   <!-- #moove_gdpr_cookie_modal -->
#   <!--/copyscapeskip-->
#   <script type="text/javascript">
#    /*Google Tag Manager for Collective Bias*/
#
#     dataLayerCBias = [{
#         'trackingID': 'UA-100208436-49',
#         'javaScriptVersion': 'analytics.js',
#         'homePageURL': 'https://acupofkims.com'
#     }];
#   </script>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PBN79J" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script type="text/javascript">
#    /*<![CDATA[*/
#     (function() {
#       window.setTimeout(function() {
#         (function(w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start': new Date().getTime(),
#                 event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src = '//www.googletagmanager.com/gtm.'+'js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayerCBias', 'GTM-PBN79J');
#       });
#     })();
#     /*]]>*/
#
#     /*End Google Tag Manager for Collective Bias*/
#   </script>
#   <iframe id="SHR" style="display: none; border: none;" title="shr-utils">
#   </iframe>
#   <div class="shareaholic-canvas shareaholic-share-buttons-container shareaholic-resolved-canvas shareaholic-ui" data-app="floated_share_buttons" id="shr_canvas3" style="visibility: visible;">
#    <div translate="no">
#     <div class="shareaholic-share-buttons-container shareaholic-ui shr-no-print shareaholic-flat shareaholic- shareaholic-floated shareaholic- shareaholic-vertical shareaholic- shareaholic-left-align shr-sharebuttons-floated shareaholic-flat shareaholic-floated shareaholic-vertical" style="top:15%">
#      <div class="shareaholic-show-container">
#       <img alt="arrow" class="shareaholic-show-hide-arrow" src="data:image/png;base64,..."/>
#      </div>
#      <div class="shareaholic-share-buttons-wrapper shareaholic-ui">
#       <div class="shareaholic-share-buttons-animation-wrapper shr-hide">
#        <div class="shareaholic-share-buttons-heading shareaholic-custom">
#         <div class="shareaholic-share-buttons-heading-text" style="line-height:normal;">
#         </div>
#        </div>
#        <ul class="shareaholic-share-buttons shareaholic-no-margin-padding-important">
#         <li class="shareaholic-share-button" data-service="twitter" style="display:list-item;" title="X (Twitter)">
#          <div class="shareaholic-share-button-container shr-outline shareaholic-service-twitter shareaholic-service-default" role="button" style="">
#           <div class="shareaholic-share-button-sizing" style="">
#            <a aria-label="Post to X (Twitter)" class="shareaholic-service-icon shareaholic-service-twitter shareaholic-service-default" href="/#shr-twitter" rel="nofollow" style="" tabindex="0">
#            </a>
#            <span class="shr-share-button-verb" style="color:#fff!important">
#             Post
#            </span>
#           </div>
#          </div>
#         </li>
#         <li class="shareaholic-share-button" data-service="facebook" style="display:list-item;" title="Facebook">
#          <div class="shareaholic-share-button-container shr-outline shareaholic-service-facebook shareaholic-service-default" role="button" style="">
#           <div class="shareaholic-share-button-sizing" style="">
#            <a aria-label="Share to Facebook" class="shareaholic-service-icon shareaholic-service-facebook shareaholic-service-default" href="/#shr-facebook" rel="nofollow" style="" tabindex="0">
#            </a>
#            <span class="shr-share-button-verb" style="color:#fff!important">
#             Share
#            </span>
#           </div>
#          </div>
#         </li>
#         <li class="shareaholic-share-button" data-service="pinterest" style="display:list-item;" title="Pinterest">
#          <div class="shareaholic-share-button-container shr-outline shareaholic-service-pinterest shareaholic-service-default" role="button" style="">
#           <div class="shareaholic-share-button-sizing" style="">
#            <a aria-label="Pin to Pinterest" class="shareaholic-service-icon shareaholic-service-pinterest shareaholic-service-default" href="/#shr-pinterest" rel="nofollow" style="" tabindex="0">
#            </a>
#            <span class="shr-share-button-verb" style="color:#fff!important">
#             Pin
#            </span>
#           </div>
#          </div>
#         </li>
#         <li class="shareaholic-share-button" data-service="email_this" style="display:list-item;" title="Email This">
#          <div class="shareaholic-share-button-container shr-outline shareaholic-service-email_this shareaholic-service-default" role="button" style="">
#           <div class="shareaholic-share-button-sizing" style="">
#            <a aria-label="Mail to Email This" class="shareaholic-service-icon shareaholic-service-email_this shareaholic-service-default" href="/#shr-email_this" rel="nofollow" style="" tabindex="0">
#            </a>
#            <span class="shr-share-button-verb" style="color:#fff!important">
#             Mail
#            </span>
#           </div>
#          </div>
#         </li>
#         <li class="shareaholic-share-button shareaholic-share-button-all" data-service="all" style="display:list-item;" title="More Options">
#          <div class="shareaholic-share-button-container shr-outline shareaholic-service-all shareaholic-service-default" role="button" style="">
#           <div class="shareaholic-share-button-sizing" style="">
#            <a aria-label="Share to More Options" class="shareaholic-service-icon shareaholic-service-all shareaholic-service-default" href="/#shr-all" rel="nofollow" style="" tabindex="0">
#            </a>
#            <span class="shr-share-button-verb" style="color:#fff!important">
#             Share
#            </span>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </div>
#       <div class="shareaholic-hide-container shr-hide shareaholic-left-alignment">
#        <img alt="arrow" class="shareaholic-show-hide-arrow shareaholic-orientation-left" src="data:image/png;base64,..."/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script async="" data-cfasync="false" id="shr-partners" src="https://partner.shareaholic.com/partners.js?location=https%3A%2F%2Facupofkims.com%2Fa-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro%2F&amp;cl=en-US&amp;id_sync=3d4a4f4e-3a26-4bef-9bae-ca8d0dd9c330&amp;pvs=1&amp;site=8da01fda899c850a74073290371e6117">
#   </script>
#   <iframe style="display: none;">
#   </iframe>
#   <script charset="" id="" type="text/javascript">
#    !function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","308519652912505");fbq("track","PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=308519652912505&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script charset="" id="" type="text/javascript">
#    window._oiqq=window._oiqq||[];_oiqq.push(["oiq_addPageLifecycle","ba2e"]);_oiqq.push(["oiq_doTag"]);(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://px.owneriq.net/stas/s/igpkg3.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();
#   </script>
#   <script async="" src="https://px.owneriq.net/j/?ref=https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/&amp;pt=igpkg3&amp;t=f%7C%22A%25205-Day%2520Itinerary%2520In%2520Philadelphia%2520From%2520a%2520Local%25E2%2580%2599s%2520Perspective%2520%252F%2520Ro%2520%257C%2520A%2520Cup%2520of%2520Kims%22&amp;s=ba2e" type="text/javascript">
#   </script>
#   <script charset="" id="" type="text/javascript">
#    (function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date;a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","//www.google-analytics.com/analytics.js","gacbias");
# if("analytics.js"=="analytics.js"){var pid="UA-100208436-49";gacbias("create",pid,"auto",{"name":"cbias1"});gacbias("cbias1.require","displayfeatures");gacbias("cbias1.set","title",document.title+"|#|"+"#1#2#3#4#5");gacbias("cbias1.send","pageview")}else{var _gaq=_gaq||[];var pid="UA-100208436-49";_gaq.push(["_setAccount",pid]);_gaq.push(["_set","title",document.title+"|#|"+"#1#2#3#4#5"]);_gaq.push(["_trackPageview"]);(function(){var ga=document.createElement("script");
# ga.type="text/javascript";ga.async=true;ga.src=("https:"==document.location.protocol?"https://ssl":"http://www")+".google-analytics.com/ga.js";var s=document.getElementsByTagName("script")[0];s.parentNode.insertBefore(ga,s)})()}gacbias("cbias2.require","displayfeatures");gacbias("cbias2.set","title",document.title+"|#|"+"#1#2#3#4#5");gacbias("cbias2.send","pageview");
#   </script>
#   <iframe src="https://px.owneriq.net/eps?pt=igpkg3&amp;pid=8972&amp;uid=Q7829866731657140254J&amp;l=true" style="display: none;" title="no content javascript process">
#   </iframe>
#   <iframe style="display: none;">
#   </iframe>
#   <div class="fd-form-popup" id="fd-form-popup-5d782884cb4d50000f51084c" style="position: fixed; top: 0; left: 0; width: 100%; height: 100%; visibility: hidden; opacity: 0; z-index: -1">
#    <iframe class="fd-form-popup__iframe" id="fd-iframe-1729700274366" scrolling="no" style="width: 100%; height: 100%; border: none">
#    </iframe>
#   </div>
#   <script async="" src="https://px.owneriq.net/stas/s/sholic.js">
#   </script>
#   <script async="" src="https://px.owneriq.net/stas/s/ch2y34.js">
#   </script>
#   <script async="" src="https://i.simpli.fi/dpx.js?cid=66111&amp;m=0&amp;sifi_tuid=37828&amp;referrer=https%3A%2F%2Facupofkims.com%2Fa-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro%2F">
#   </script>
#   <img alt="crwdcntrl" src="https://sync.crwdcntrl.net/map/c=9193/tp=SHLC/tpid=3d4a4f4e-3a26-4bef-9bae-ca8d0dd9c330" style="height: 0px; width: 0px; border: 0px; display: none;"/>
#   <script async="" src="https://ml314.com/taglw.aspx?239">
#   </script>
#   <img alt="score" src="https://sb.scorecardresearch.com/p?c1=7&amp;c2=19376307&amp;c3=1&amp;cv=3.6.0&amp;cj=1" style="height: 0px; width: 0px; border: 0px; display: none;"/>
#   <script async="" src="https://cdn.tynt.com/afsh.js">
#   </script>
#   <script async="" src="https://px.owneriq.net/j/?ref=https://acupofkims.com/a-5-day-itinerary-in-philadelphia-from-a-locals-perspective-ro/&amp;pt=igpkg3,sholic,ch2y34&amp;t=m%7C%22Bassett%22,d%7C%22Media%22,d%7C%22Shopping%2520Services%22&amp;s=inte,4y6h" type="text/javascript">
#   </script>
#   <script async="" src="https://ml314.com/taglw.aspx?239">
#   </script>
#   <iframe src="https://px.owneriq.net/eps?pt=sholic&amp;pid=1693&amp;uid=Q7829866731657140254J&amp;l=true" style="display: none;" title="no content javascript process">
#   </iframe>
#   <iframe src="https://px.owneriq.net/eps?pt=ch2y34&amp;pid=6836&amp;uid=Q7829866731657140254J&amp;l=true" style="display: none;" title="no content javascript process">
#   </iframe>
#  </body>
# </html>
