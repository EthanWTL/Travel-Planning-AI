# %%
import os
import re
import importlib
import json
from langchain.chat_models import ChatOpenAI
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
from Prompts.ReACT.prompts import zeroshot_react_agent_prompt
from typing import List, Dict, Any
from pandas import DataFrame


OPENAI_API_KEY = os.getenv('OPEN_AI_API')
actionMapping = {"AccommodationSearch":"accommodations", "RestaurantSearch":"restaurants", "AttractionSearch":"attraction","BusinessClusterSearch":"nearby","Planner":"planner"}

# %%
class ReactAgent:
    def __init__(self,
                 react_llm_name,
                 planner_llm_name,
                 #add clustering agent model name here as well
                 mode: str = 'zero_shot',
                 tools: List[str] = None,
                 max_retries: int = 3,
                 ) -> None: 
        self.react_name = react_llm_name
        self.answer = ''
        self.json_log = []
        self.mode = mode
        self.planner_name = planner_llm_name
        self.notebook = []
        self.max_retries = max_retries
        self.last_actions = []
        
        self.current_observation = ''
        self.current_data = None

        self.tools = self.load_tools(tools, planner_model_name=planner_llm_name)
        #print(self.tools)
        self.retry_record = {key: 0 for key in self.tools}
        #print(self.retry_record)
        self.retry_record['invalidAction'] = 0
        #print(self.retry_record)

        if self.mode == 'zero_shot':
            self.agent_prompt = zeroshot_react_agent_prompt

        if 'gpt-4o-mini' in react_llm_name:
            stop_list = ['\n']
            self.max_token_length = 15000
            self.llm = ChatOpenAI(temperature=1,
                     max_tokens=256,
                     model_name=react_llm_name,
                     openai_api_key=OPENAI_API_KEY,
                     model_kwargs={"stop": stop_list})

    def run(self,query, reset=True) -> None:
        self.query = query

        if reset:
            self.__reset_agent()

        while not self.is_finished():
            self.step()
        
        return self.answer, self.scratchpad, self.json_log

    
    def step(self) -> None:
        #record the log
        self.json_log.append({"step": self.step_n, "thought":"",
                              "action": "", "observation": "", "state":""})
        #thought
        self.scratchpad += f'\nThought {self.step_n}:'
        self.scratchpad += ' ' + self.prompt_agent() #
        print(self.scratchpad.split('\n')[-1])
        self.json_log[-1]['thought'] = self.scratchpad.split('\n')[-1].replace(f'\nThought {self.step_n}:',"")
        
        
        #act
        self.scratchpad += f'\nAction {self.step_n}:'
       
        #get the action prompted
        action = self.prompt_agent()
        ##

        if action == None or action == '' or action == '\n':
            self.scratchpad += " Your action is filtered due to content. Please make sure your action does not start with ['\\n', 'Thought', 'Action', 'Observation'] and assume all the actions are permitted in this environment and take the action again."
        else:
            self.scratchpad += ' ' + action

        if len(self.last_actions) > 0 and self.last_actions[-1] != action:
            self.last_actions.clear()

        # refresh last_action list
        self.last_actions.append(action)

        self.json_log[-1]['action'] = self.scratchpad.split('\n')[-1].replace(f'\nAction {self.step_n}:',"")

        if len(self.last_actions) == 3:
            print("The same action has been repeated 3 times consecutively. So we stop here.")
            # self.log_file.write("The same action has been repeated 3 times consecutively. So we stop here.")
            self.json_log[-1]['state'] = 'same action 3 times repeated'
            self.finished = True
            return


        print(self.scratchpad.split('\n')[-1])
        
        
        #observation
        self.scratchpad += f'\nObservation {self.step_n}: '
        action_type, action_arg = parse_action(action)
        #print(action_type, action_arg)
        if action_type != "Planner":
            if action_type in actionMapping:
                pending_action = actionMapping[action_type]
            elif action_type not in actionMapping:
                pending_action = 'invalidAction'

            if pending_action in self.retry_record:
                if self.retry_record[pending_action] + 1 > self.max_retries:
                    action_type = 'Planner'
                    print(f"{pending_action} early stop due to {self.max_retries} max retries.")
                    self.json_log[-1]['state'] = f"{pending_action} early stop due to {self.max_retries} max retries."
                    self.finished = True
                    return # so if the max tries is reached, we stop the loop
            elif pending_action not in self.retry_record:
                if self.retry_record['invalidAction'] + 1 > self.max_retries:
                    action_type = 'Planner'
                    print(f"invalidAction Early stop due to {self.max_retries} max retries.")
                    # self.log_file.write(f"invalidAction early stop due to {self.max_retries} max retries.")
                    self.json_log[-1]['state'] = f"invalidAction early stop due to {self.max_retries} max retries."
                    self.finished = True
                    return

        if action_type == 'AccommodationSearch':
            try:
                if validate_accommodation_parameters_format(action_arg):
                    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                    self.current_data = self.tools['accommodations'].run(action_arg.split(',')[0],[p.strip() for p in action_arg.split('[')[1].strip('[]').split(',')])
                    self.current_observation = str(to_string(self.current_data))
                    self.scratchpad += self.current_observation
                    self.notebook.append({'Description': 'Accommodation Choice', 'Content': self.current_data})
                    self.__reset_record()
                    self.json_log[-1]['state'] = 'Successful'
                    
            except ValueError as e:
                print(e)
                self.retry_record['accommodations'] += 1
                self.current_observation = str(e)
                self.scratchpad += str(e)
                self.json_log[-1]['state'] = f'Illegal args. Parameter Error'
            except Exception as e:
                print(e)
                self.retry_record['accommodations'] += 1
                self.current_observation = f'Illegal Accommodation Search. Please try again.'
                self.scratchpad += f'Illegal Accommodation Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        elif action_type == 'AttractionSearch':
            try:
                if validate_attraction_parameters_format(action_arg):
                    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                    self.current_data = self.tools['attractions'].run(action_arg.split(',')[0],[action_arg.split(',')[1].strip()[1:][:-1]])
                    self.current_observation = str(to_string(self.current_data))
                    self.scratchpad += self.current_observation 
                    self.notebook.append({'Description': 'Attraction Choice', 'Content': self.current_data})
                    self.__reset_record()
                    self.json_log[-1]['state'] = f'Successful'
            except ValueError as e:
                print(e)
                self.retry_record['attractions'] += 1
                self.current_observation = str(e)
                self.scratchpad += str(e)
                self.json_log[-1]['state'] = f'Illegal args. Parameter Error'
            except Exception as e:
                print(e)
                self.retry_record['attractions'] += 1
                self.current_observation = f'Illegal Attraction Search. Please try again.'
                self.scratchpad += f'Illegal Attraction Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        elif action_type == 'RestaurantSearch': #action_arg = 'Cheap Budget, Indian, [Good Flavor, Good Value]'
            try:
                if validate_restaurant_parameters_format(action_arg):
                    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                    self.current_data = self.tools['restaurants'].run(action_arg.split('[')[0].split(',')[0].strip(),action_arg.split('[')[0].split(',')[1].strip(),[a.strip() for a in action_arg.split('[')[1].strip()[:-1].split(',')])
                    self.current_observation = str(to_string(self.current_data))
                    self.scratchpad += self.current_observation
                    self.notebook.append({'Description': 'Restaurant Choice', 'Content': self.current_data})
                    self.__reset_record()
                    self.json_log[-1]['state'] = f'Successful'
            except ValueError as e:
                print(e)
                self.retry_record['restaurants'] += 1
                self.current_observation = str(e)
                self.scratchpad += str(e)
                self.json_log[-1]['state'] = f'Illegal args. Parameter Error'
            except Exception as e:
                print(e)
                self.retry_record['restaurants'] += 1
                self.current_observation = f'Illegal Restaurant Search. Please try again.'
                self.scratchpad += f'Illegal Restaurant Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        elif action_type == 'BusinessClusterSearch': #action_arg = 'Cheap Budget, Indian, [Good Flavor, Good Value]'
            try:
                self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                self.current_data = self.tools['nearby'].run(self.notebook)
                self.current_observation = str(to_string(self.current_data))
                self.scratchpad += self.current_observation
                self.notebook.append({'Description': 'Restaurant Choice', 'Content': self.current_data})
                self.__reset_record()
                self.json_log[-1]['state'] = f'Successful'
            
            except Exception as e:
                print(e)
                self.retry_record['restaurants'] += 1
                self.current_observation = f'Illegal Restaurant Search. Please try again.'
                self.scratchpad += f'Illegal Restaurant Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        #elif action_type == 'NotebookWrite':
        #    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
        #    self.current_observation = str(self.tools['notebook'].write(self.current_data, action_arg))
        #    self.scratchpad  +=  self.current_observation
        #    self.json_log[-1]['state'] = f'Successful'

        elif action_type == 'Planner':
            #print(self.notebook)
            self.current_observation = str(self.tools['planner'].run(str(self.notebook),action_arg))
            self.scratchpad  +=  self.current_observation
            self.answer = self.current_observation
            self.json_log[-1]['state'] = f'Successful'
        else:
            self.retry_record['invalidAction'] += 1
            self.current_observation = 'Invalid Action. Valid Actions are AccommodationSearch[Budget,Preference] / AttractionSearch[Budget, Preference] / RestaurantSearch[Budget, Cuisine, Preference]/ Planner[Query].'
            self.scratchpad += self.current_observation
            self.json_log[-1]['state'] = f'invalidAction'
        
        #print(f'Observation {self.step_n}: ' + self.current_observation+'\n')
        # rite(f'Observation {self.step_n}: ' + self.current_observation+'\n')
        self.json_log[-1]['observation'] = self.current_observation
        self.step_n += 1

        if action_type and action_type == 'Planner':
            self.finished = True
            self.answer = self.current_observation

            #print(self.scratchpad)
            #print(self.json_log)
            #print(self.notebook) 
        return
    
    
    
    
    def is_finished(self) -> bool:
        return self.finished
    
    #def is_halted(self) -> bool:
    #    return ((self.step_n > self.max_steps) or (
    #                len(self.enc.encode(self._build_agent_prompt())) > self.max_token_length)) and not self.finished
    
    def __reset_agent(self) -> None:
        self.step_n = 1
        self.finished = False
        self.answer = ''
        self.scratchpad: str = ''
        self.json_log = []

    def prompt_agent(self) -> str:
        #print("we prompt the agents")
        while True:
            request = format_step(self.llm([HumanMessage(content=self._build_agent_prompt())]).content)
            #print("here is the raw request: === ", request)
            return request  
        
    def __reset_record(self) -> None:
        self.retry_record = {key: 0 for key in self.retry_record}
        self.retry_record['invalidAction'] = 0

    def _build_agent_prompt(self) -> str:
        if self.mode == "zero_shot":
            return self.agent_prompt.format(
                query=self.query,
                scratchpad=self.scratchpad)
        
    def load_tools(self, tools: List[str], planner_model_name=None) -> Dict[str, Any]:
        tools_map = {}
        for tool_name in tools:
            module = importlib.import_module("tools.{}.apis".format(tool_name)) #
            
            # Avoid instantiating the planner tool twice, need to finish planner module before uncomment this
            if tool_name == 'planner' and planner_model_name is not None:
                tools_map[tool_name] = getattr(module, tool_name[0].upper()+tool_name[1:])(model_name=planner_model_name)
            else:
                tools_map[tool_name] = getattr(module, tool_name[0].upper()+tool_name[1:])()
        #print(tools_map)
        return tools_map
        

def format_step(step: str) -> str:
    return step.strip('\n').strip().replace('\n', '')

def parse_action(string):
    if ('BusinessClusterSearch' not in string):
        pattern = r'^(\w+)\[(.+)\]$'
        match = re.match(pattern, string)
        action_type = match.group(1)
        action_arg = match.group(2)
    else:
        action_type = 'BusinessClusterSearch'
        action_arg = ''
    return action_type,action_arg

#def parse action arg

def to_string(data) -> str:
    if data is not None:
        if type(data) == DataFrame:
            return data.to_string(index=False)
        else:
            return str(data)
    else:
        return str(None)
    
def validate_accommodation_parameters_format(action_arg):
    pattern = r"(.*\s*.*)\s*,\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, preference list.")
    budget = match.group(1).lower()
    preference_list = match.group(2)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget, and expensive budget. Please try again.")

    #preference
    preference = preference_list.split(',')
    preference_core = [p.lower().strip().split(' ')[-1].strip() for p in preference]
    preferenceInRange = True
    preferenceAccepted = ['location','service','safety','quality']
    for p in preference_core:
        if p not in preferenceAccepted:
            preferenceInRange = False

    if not preferenceInRange:
        raise ValueError("Wrong preference Input. Please try again.")
    return True
    
def validate_attraction_parameters_format(action_arg):
    pattern = r"(.*\s*.*)\s*,\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, Preference list.")
    budget = match.group(1).lower()
    preference_list = match.group(2)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget, and expensive budget. Please try again.")

    preference = preference_list.strip().split(',')
    if(len(preference) > 1 ):
        raise ValueError("Attraction only allows one preference. Please try again")
    if '-' in preference[0]:
        preference_core = preference[0].strip().split('-')[0].lower()
    else:
        preference_core = preference[0].strip().split(' ')[0].lower()
    preferenceAccepted = ["family","history","activity","nature","food","shopping"]
    preferenceIsInRange = False
    if(preference_core in preferenceAccepted):
        preferenceIsInRange = True
    if not preferenceIsInRange:
        raise ValueError("Preference parameter invalid. Only family oriented / history oriented / activity oriented / nature oriented / food oriented / and shopping oriented are allowed. Please try again.")
    return True

def validate_restaurant_parameters_format(action_arg):
    pattern = r"(.*\s*.*),\s*(.*),\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, cuisine, preference list.")
    budget = match.group(1).lower()
    cuisine = match.group(2).lower()
    preference_list = match.group(3)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    #print(budget)
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget and expensive budget. Please try again.")

    cuisine_accepted = ["us","mexican","irish","french","italian","greek","indian","chinese","japanese","korean","vietnamese","thai","asian fusion","middle eastern"]
    #print(cuisine)
    cuisineInRange = False
    if cuisine in cuisine_accepted:
        cuisineInRange = True
    if not cuisineInRange:
        raise ValueError("Cuisine not valid. Accepted cuisine is: US / Mexican / Irish / French / Italian / Greek / Indian / Chinese / Japanese / Korean / Vietnamese / Thai / Asian Fusion and Middle Eastern. Please try again.")

    preference_list = [p.lower().strip() for p in preference_list.split(',')]
    preference_core = [p.strip().split(' ')[-1] for p in preference_list]
    #print(preference_core)

    preferenceInRange = True
    preferenceAccepted = ['',"flavor","freshness","service","environment","value"]
    for p in preference_core:
        if p not in preferenceAccepted:
            preferenceInRange = False

    if not preferenceInRange:
        raise ValueError("Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.")    
    return True

# %%
tools_list = ["attractions","accommodations","restaurants","nearby","planner"]
model_name = 'gpt-4o-mini'

agent = ReactAgent(tools=tools_list,react_llm_name = model_name, planner_llm_name = model_name)

for filename in os.listdir('Prompts/prompts_routesOP'):
    
    #for testing
    #if filename != "Prompt_1.txt":
    #    continue
        
    index = filename[:-4][7:]
    with open(f'Prompts/prompts_routesOP/{filename}', 'r') as file:
        query = file.read()
    planner_results, scratchpad, action_log  = agent.run(query)
    with open(f'Outputs/plans/gpt4omini/Plan_{index}.txt', 'w') as f:
        f.write(planner_results)
    with open(f'Outputs/scratchpads/gpt4omini/Plan_{index}.txt', 'w') as f:
        f.write(scratchpad)
    with open(f'Outputs/logs/gpt4omini/Plan_{index}.json', 'w') as f:
        json.dump(action_log, f)
# Out:
# n:\Travel-Planning-AI\Task 3 ToolUse\tools\planner\apis.py:16: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   self.llm = ChatOpenAI(model_name=model_name, temperature=0, max_tokens=15000, openai_api_key=OPENAI_API_KEY)
# C:\Users\Ethan\AppData\Local\Temp\ipykernel_9948\39984212.py:260: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   request = format_step(self.llm([HumanMessage(content=self._build_agent_prompt())]).content)
# Thought 1: To generate a well-organized travel itinerary for a 3-day trip focusing on cheap, activity-oriented attractions, Indian restaurants with good flavor and value, and accommodations in a good location, I will first gather information on each category: accommodation, attractions, and restaurants. I will also need to look into spatial clustering to optimize the route.
# Action 1: AccommodationSearch[Cheap Budget,[Good Location]]
# AccommodationSearch Cheap Budget,[Good Location]
# Thought 2: I have gathered a list of accommodations available within a cheap budget that are located in good areas. Next, I will look for Indian restaurants that meet the specified criteria of good flavor and good value.
# Action 2: RestaurantSearch[Cheap Budget, Indian, [Good Flavor, Good Value]]
# RestaurantSearch Cheap Budget, Indian, [Good Flavor, Good Value]
# Thought 3: I have collected a good list of Indian restaurants offering good flavor and good value within a cheap budget. Now, I will proceed to gather information on activity-oriented attractions that fit the budget requirements.
# Action 3: AttractionSearch[Cheap budget,[Activity Oriented]]
# AttractionSearch Cheap budget,[Activity Oriented]
# Thought 4: I have obtained a list of activity-oriented attractions that fit the cheap budget requirement. Now, I will need to analyze the spatial clustering of the accommodations, restaurants, and attractions to optimize the itinerary for each day.
# Action 4: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 5: To create an organized travel itinerary, I now have all the necessary information regarding accommodations, restaurants, and attractions that will allow me to optimize the routes for each day. I will proceed to formulate the detailed 3-day trip plan based on spatial clustering and the gathered insights.
# Action 5: Planner[Generate a detailed travel itinerary for a 3-day trip with a cheap budget focusing on activity-oriented attractions, Indian restaurants with good flavor and good value, and accommodations in a good location.]
# Planner Generate a detailed travel itinerary for a 3-day trip with a cheap budget focusing on activity-oriented attractions, Indian restaurants with good flavor and good value, and accommodations in a good location.
# Thought 1: To create a detailed travel itinerary for a 4-day trip with an expensive budget, I need to gather information about accommodations, attractions focused on shopping, Korean restaurants, and related business information to optimize routes. I'll start by searching for suitable accommodations that are of good quality and in a good location.
# Action 1: AccommodationSearch[Expensive Budget,[Good Location, Good Quality]]
# AccommodationSearch Expensive Budget,[Good Location, Good Quality]
# Thought 2: I have collected suitable accommodations that are of good quality and in good locations. Next, I will search for shopping-oriented attractions that match the expensive budget specified.
# Action 2: AttractionSearch[Expensive Budget,[Shopping Oriented]]
# AttractionSearch Expensive Budget,[Shopping Oriented]
# Thought 3: Now that I have gathered information about accommodations and shopping-oriented attractions, I need to find Korean restaurants that fit within the expensive budget and meet the preferences outlined in the query.
# Action 3: RestaurantSearch[Expensive Budget,Korean,[Good Flavor, Good Value]]
# RestaurantSearch Expensive Budget,Korean,[Good Flavor, Good Value]
# Thought 4: I have obtained the necessary information about accommodations, shopping-oriented attractions, and Korean restaurants that meet the budget and preferences outlined. Next, I will compile a list of business clusters to optimize the arrangement of locations for each day of the trip.
# Action 4: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 5: I have gathered information regarding accommodations, shopping-oriented attractions, and Korean restaurants, as well as the spatial clustering data to optimize the itinerary. Now, I'll create a structured travel itinerary for the 4-day trip.
# Action 5: Planner[Generate a detailed travel itinerary for a 4-day trip including shopping-oriented attractions, Korean restaurants, and accommodations with good quality and location.]
# Planner Generate a detailed travel itinerary for a 4-day trip including shopping-oriented attractions, Korean restaurants, and accommodations with good quality and location.
# Thought 1: I need to gather comprehensive information on accommodations, restaurants serving Greek cuisine, and family-oriented attractions to create a structured 4-day travel itinerary. The goal is to focus on a moderate budget and ensure that the locations are optimized for convenience.
# Action 1: AccommodationSearch[Moderate Budget,[Good Location, Good Service]]
# AccommodationSearch Moderate Budget,[Good Location, Good Service]
# Thought 2: I have collected several hotel options that fit the criteria of good service and excellent locations within a moderate budget. Next, I need to find dining options that serve Greek cuisine and have a good environment.
# Action 2: RestaurantSearch[Moderate Budget, Greek, [Good Environment]]
# RestaurantSearch Moderate Budget, Greek, [Good Environment]
# Thought 3: I now have a selection of restaurants that offer Greek cuisine with good environments at a moderate budget. The next step is to find family-oriented attractions that align with the same budget and preferences for the itinerary.
# Action 3: AttractionSearch[Moderate Budget, [Family Oriented]]
# AttractionSearch Moderate Budget, [Family Oriented]
# Thought 4: Now that I have gathered a variety of accommodations, restaurants serving Greek cuisine, and family-oriented attractions, the next step will be to analyze the spatial relationships among the collected information to optimize the itinerary for each day.
# Action 4: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 5: I can now use the collected information about accommodations, dining options, and attractions to create a detailed travel itinerary. Optimizing the route will help in organizing these recommendations by ensuring nearby locations are grouped together for convenience on each day.
# Action 5: Planner[Please generate a detailed travel itinerary for a 4-day trip with a moderate budget, focusing on family-oriented attractions, including Greek cuisine restaurants and recommending quality accommodations in prime locations, while optimizing the routes of attractions.]
# Planner Please generate a detailed travel itinerary for a 4-day trip with a moderate budget, focusing on family-oriented attractions, including Greek cuisine restaurants and recommending quality accommodations in prime locations, while optimizing the routes of attractions.
# Thought 1: I need to gather information on expensive accommodations with a focus on good safety. This will serve as the foundation for the travel itinerary.
# Action 1: AccommodationSearch[Expensive budget,[Good Safety]]
# AccommodationSearch Expensive budget,[Good Safety]
# Thought 2: I have gathered the information on accommodations that prioritize good safety for an expensive budget. The next step is to find nature-oriented attractions that match this travel plan.
# Action 2: AttractionSearch[Expensive budget,[Nature Oriented]]
# AttractionSearch Expensive budget,[Nature Oriented]
# Thought 3: I've successfully gathered information on nature-oriented attractions suitable for an expensive budget. Now, I need to find Irish restaurants that match the criteria of high quality for the trip, which would complement the surrounding attractions and accommodations.
# Action 3: RestaurantSearch[Expensive budget, Irish, [Good Flavor, Good Value]]
# RestaurantSearch Expensive budget, Irish, [Good Flavor, Good Value]
# Thought 4: I need to adjust my search to find high-quality Irish restaurants without restricting by value since there were no results. I will focus on expensive Irish restaurants to ensure a good dining experience during the trip.
# Action 4: RestaurantSearch[Expensive budget, Irish, []]
# RestaurantSearch Expensive budget, Irish, []
# Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.
# Thought 5: I need to refine my search for Irish restaurants by including some of the acceptable quality preferences, since value was not returning any results. I will focus on good flavor and good service to ensure an enjoyable dining experience.
# Action 5: RestaurantSearch[Expensive budget, Irish, [Good Flavor, Good Service]]
# RestaurantSearch Expensive budget, Irish, [Good Flavor, Good Service]
# Thought 6: I need to shift my strategy for finding high-quality Irish restaurants. Since my previous attempts did not yield results, I should prioritize the best-rated Irish restaurants without overly restrictive preferences. This approach should help locate a suitable dining option for the itinerary.
# Action 6: RestaurantSearch[Expensive budget, Irish, [Good Flavor, Good Environment]]
# RestaurantSearch Expensive budget, Irish, [Good Flavor, Good Environment]
# Thought 7: I now have gathered information about accommodations, nature-oriented attractions, and Irish restaurants suitable for an expensive budget. To create a well-structured itinerary, I need to investigate business clustering to optimize the arrangement of attractions and accommodations in one day.
# Action 7: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 8: I have successfully gathered the necessary information regarding accommodations, attractions, and restaurants. Now, I will formulate the travel itinerary for the 2-day trip, ensuring a logical and enjoyable flow while optimizing for proximity.
# Action 8: Planner[Generate a detailed travel itinerary for a 2-day trip with an expensive budget focusing on nature-oriented attractions, including recommendations for Irish restaurants, and suggesting accommodations that prioritize good safety.]
# Planner Generate a detailed travel itinerary for a 2-day trip with an expensive budget focusing on nature-oriented attractions, including recommendations for Irish restaurants, and suggesting accommodations that prioritize good safety.
# Thought 1: I need to gather information about accommodations that prioritize good safety, good location, and good quality, attractions that are activity-oriented and fit a cheap budget, and Middle Eastern restaurants that are also budget-friendly. This data will help construct a detailed travel itinerary for a 3-day trip.
# Action 1: AccommodationSearch[Cheap budget,[Good Safety, Good Location, Good Quality]]
# AccommodationSearch Cheap budget,[Good Safety, Good Location, Good Quality]
# Thought 2: I now have information regarding accommodation. The Dwight D has good safety, good location, and good quality, making it suitable for the trip. I still need to gather details on activity-oriented attractions that are budget-friendly.
# Action 2: AttractionSearch[Cheap budget,[Activity-Oriented]]
# AttractionSearch Cheap budget,[Activity-Oriented]
# Thought 3: I now have information on budget-friendly activity-oriented attractions. I need to gather details on Middle Eastern restaurants that fit within a cheap budget so that the itinerary can be comprehensive and include meal options that align with the stated preferences.
# Action 3: RestaurantSearch[Cheap budget, Middle Eastern, []]
# RestaurantSearch Cheap budget, Middle Eastern, []
# Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.
# Thought 4: I'll refine my search for budget-friendly Middle Eastern restaurants that meet at least one of the quality preferences.
# Action 4: RestaurantSearch[Cheap budget, Middle Eastern, [Good Flavor, Good Value]]
# RestaurantSearch Cheap budget, Middle Eastern, [Good Flavor, Good Value]
# Thought 5: I have gathered relevant information about accommodations, attractions, and dining options. The collected data includes a variety of budget-friendly accommodations with good safety, good locations, and good quality, along with activity-oriented attractions suitable for a cheap budget. Additionally, I found several Middle Eastern restaurants that meet the required preferences for good flavor and good value. Now, I will optimize the arrangement of attractions and accommodations for each day to ensure a smooth travel itinerary.
# Action 5: Planner[Generate a detailed itinerary for a 3-day trip focusing on budget-friendly accommodations, activity-oriented attractions, and Middle Eastern restaurants with good flavor and good value.]
# Planner Generate a detailed itinerary for a 3-day trip focusing on budget-friendly accommodations, activity-oriented attractions, and Middle Eastern restaurants with good flavor and good value.
# Thought 1: To create an organized travel itinerary focusing on history-oriented attractions, Vietnamese dining options, and quality accommodations within a moderate budget, I will start by gathering the necessary information.
# Action 1: AccommodationSearch[Moderate Budget,[Good Location, Good Service]]
# AccommodationSearch Moderate Budget,[Good Location, Good Service]
# Thought 2: Now that I have a list of possible accommodations, I will proceed to find history-oriented attractions that fit a moderate budget.
# Action 2: AttractionSearch[Moderate Budget,[History Oriented]]
# AttractionSearch Moderate Budget,[History Oriented]
# Thought 3: To complete the itinerary, I'll now find Vietnamese restaurants that fit a moderate budget. This will ensure that dining options align with the overall plan.
# Action 3: RestaurantSearch[Moderate Budget, Vietnamese, [Good Flavor, Good Value]]
# RestaurantSearch Moderate Budget, Vietnamese, [Good Flavor, Good Value]
# Thought 4: I need to analyze the gathered data to optimize the itinerary, focusing on proximity between accommodations, attractions, and dining options. Additionally, it is important to assess the business clusters for efficient routing.
# Action 4: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 5: Now that I have all the necessary information collected, I will proceed to create a travel itinerary for the 4-day trip focusing on history-oriented attractions, dining at Vietnamese restaurants, and recommending quality accommodations. This will ensure that all recommendations are structured chronologically, optimizing routes and closeness for a seamless experience.
# Action 5: Planner[Generate a detailed travel itinerary for a 4-day trip focusing on history-oriented attractions, Vietnamese dining, and quality accommodations within a moderate budget.]
# Planner Generate a detailed travel itinerary for a 4-day trip focusing on history-oriented attractions, Vietnamese dining, and quality accommodations within a moderate budget.
# Thought 1: I need to gather information related to accommodations, restaurants, and attractions that fit the user's requirements for a 4-day trip focused on history, while keeping the budget cheap. I will start by searching for accommodations that prioritize safety.
# Action 1: AccommodationSearch[Cheap budget, [Good Safety]]
# AccommodationSearch Cheap budget, [Good Safety]
# Thought 2: I have gathered accommodation options that emphasize safety. Now I will look for history-oriented attractions that fit the cheap budget to ensure a comprehensive travel itinerary.
# Action 2: AttractionSearch[Cheap budget, [History Oriented]]
# AttractionSearch Cheap budget, [History Oriented]
# Thought 3: Now that I have information on accommodations and history-oriented attractions, I will look for Vietnamese restaurants that fit a cheap budget and are well-rated. This will enable the user to have a variety of dining options that align with their preferences.
# Action 3: RestaurantSearch[Cheap budget, Vietnamese, [Good Flavor, Good Value]]
# RestaurantSearch Cheap budget, Vietnamese, [Good Flavor, Good Value]
# Thought 4: I now have the necessary information on cheap accommodations, history-oriented attractions, and Vietnamese restaurants that are well-rated and provide good flavor and value. Next, I will analyze the spatial clustering of these businesses to optimize the routes of attractions for each day of the trip.
# Action 4: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 5: I have gathered sufficient information on accommodations, history-oriented attractions, and Vietnamese restaurants. Additionally, I have analyzed the spatial clustering of these businesses to ensure the itinerary is optimized for each day of travel. Now I will construct a detailed 4-day travel itinerary based on the collected data.
# Action 5: Planner[Generate a detailed travel itinerary for a 4-day trip focused on history-oriented attractions, cheap budget, and well-rated Vietnamese restaurants.]
# Planner Generate a detailed travel itinerary for a 4-day trip focused on history-oriented attractions, cheap budget, and well-rated Vietnamese restaurants.
# Thought 1: To create a detailed travel itinerary for a 2-day trip with a moderate budget focusing on activity-oriented attractions, Greek restaurants, and accommodations with good safety, various information needs to be gathered first.
# Action 1: AccommodationSearch[Moderate Budget,[Good Safety]]
# AccommodationSearch Moderate Budget,[Good Safety]
# Thought 2: Based on the gathered accommodation options that prioritize good safety, I now need to find attractions that are activity-oriented and fit within a moderate budget. This will help set up a balanced itinerary that focuses on engaging experiences during the trip.
# Action 2: AttractionSearch[Moderate Budget,[Activity Oriented]]
# AttractionSearch Moderate Budget,[Activity Oriented]
# Thought 3: I have gathered accommodations and attractions that fit the user's preferences. Now, I need to find Greek restaurants within a moderate budget to include in the itinerary. This is crucial for ensuring a complete dining experience throughout the trip.
# Action 3: RestaurantSearch[Moderate Budget, Greek, []]
# RestaurantSearch Moderate Budget, Greek, []
# Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.
# Thought 4: I need to adjust my search for Greek restaurants to include preferences related to quality, such as taste and service, in order to find suitable dining options for the itinerary during the trip.
# Action 4: RestaurantSearch[Moderate Budget, Greek, [Good Flavor, Good Value, Good Service]]
# RestaurantSearch Moderate Budget, Greek, [Good Flavor, Good Value, Good Service]
# Thought 5: To create a structured itinerary, I now have a list of accommodations, activity-oriented attractions, and Greek restaurants with good service and flavor. The next step will be to determine the business clusters to optimize the daily routing of the attractions and dining options. This will help ensure that locations that are close to one another are scheduled together.
# Action 5: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 6: Now that I have compiled the necessary information regarding accommodations, attractions, Greek restaurants, and business clusters, I can begin to structure the travel itinerary for a 2-day trip. The focus will be on activity-oriented experiences with proper attention to dining and lodging preferences, ensuring optimal routing of attractions and restaurants.
# Action 6: Planner[Generate a detailed travel itinerary for a 2-day trip with a moderate budget, focusing on activity-oriented attractions, Greek restaurants, and accommodations that prioritize good safety. Organize all recommendations chronologically for each day and ensure optimal routing of attractions.]
# Planner Generate a detailed travel itinerary for a 2-day trip with a moderate budget, focusing on activity-oriented attractions, Greek restaurants, and accommodations that prioritize good safety. Organize all recommendations chronologically for each day and ensure optimal routing of attractions.
# Thought 1: I need to gather information for a 3-day trip itinerary focused on activity-oriented attractions, with a cheap budget. The accommodations should prioritize good safety, and I'll also look for recommendations for Chinese restaurants. This will involve searching for suitable accommodations, attractions, and restaurants that align with these requirements.
# Action 1: AccommodationSearch[Cheap budget,[Good Safety]]
# AccommodationSearch Cheap budget,[Good Safety]
# Thought 2: I have gathered a selection of accommodations that prioritize safety within a cheap budget. Next, I'll search for attractions that are activity-oriented and also within a cheap budget to ensure a well-structured itinerary.
# Action 2: AttractionSearch[Cheap budget,[Activity Oriented]]
# AttractionSearch Cheap budget,[Activity Oriented]
# Thought 3: I have collected information about accommodations and attractions that match the criteria for the 3-day itinerary with a cheap budget focusing on activity-oriented attractions and safe accommodations. Now, I will search for suitable Chinese restaurants to complete the itinerary.
# Action 3: RestaurantSearch[Cheap budget, Chinese, [Good Value, Good Service]]
# RestaurantSearch Cheap budget, Chinese, [Good Value, Good Service]
# Thought 4: I have gathered the necessary information on accommodations that prioritize safety, affordable attractions focused on activities, and a selection of Chinese restaurants that provide good value and service. The next step is to organize these elements into a well-structured and chronological 3-day itinerary.
# Action 4: Planner[Generate a detailed travel itinerary for a 3-day trip with a cheap budget, focused on activity-oriented attractions, Chinese restaurant recommendations, and accommodations prioritizing good safety.]
# Planner Generate a detailed travel itinerary for a 3-day trip with a cheap budget, focused on activity-oriented attractions, Chinese restaurant recommendations, and accommodations prioritizing good safety.
# Thought 1: I need to collect information for a 4-day family trip focusing on cheap budget options, family-oriented attractions, Middle Eastern restaurants, and good quality accommodations. It’s essential to gather the right data for attractions, restaurants, and accommodations that closely align with each other for optimal travel routes.
# Action 1: AccommodationSearch[Cheap budget,[Good Quality]]
# AccommodationSearch Cheap budget,[Good Quality]
# Thought 2: I have collected some accommodation options that are good quality and fit within a cheap budget. Next, I need to find family-oriented attractions that are also inexpensive to ensure they align with the trip's focus.
# Action 2: AttractionSearch[Cheap budget, [Family Oriented]]
# AttractionSearch Cheap budget, [Family Oriented]
# Thought 3: Next, I need to find Middle Eastern restaurants that fit within a cheap budget and have good quality. This is essential to ensure that the dining experiences align with the family's preferences as well.
# Action 3: RestaurantSearch[Cheap budget, Middle Eastern, [Good Quality]]
# RestaurantSearch Cheap budget, Middle Eastern, [Good Quality]
# Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.
# Thought 4: I need to adjust the restaurant search to focus on the acceptable preferences for Middle Eastern restaurants. I should choose from the valid options such as good flavor, good service, good value, etc. It's crucial to ensure an excellent dining experience for the family during the trip.
# Action 4: RestaurantSearch[Cheap budget, Middle Eastern, [Good Flavor, Good Value]]
# RestaurantSearch Cheap budget, Middle Eastern, [Good Flavor, Good Value]
# Thought 5: I have successfully gathered relevant information regarding accommodations, attractions, and restaurants. Now, I need to consolidate this information to enable effective planning for the trip while ensuring that the attractions and accommodations are arranged conveniently for each day.
# Action 5: BusinessClusterSearch[]
# BusinessClusterSearch
# Thought 6: I have successfully obtained data regarding accommodations, attractions, and restaurants suitable for a family trip on a budget. Next, I'll proceed to generate a detailed itinerary for the 4-day trip, ensuring to organize the information chronologically and optimize the routes based on spatial clustering to enhance convenience for the family.
# Action 6: Planner[Generate a detailed travel itinerary for a 4-day trip with a cheap budget focusing on family-oriented attractions, including recommendations for Middle Eastern restaurants and suggesting good quality accommodations.]
# Planner Generate a detailed travel itinerary for a 4-day trip with a cheap budget focusing on family-oriented attractions, including recommendations for Middle Eastern restaurants and suggesting good quality accommodations.
# Thought 1: Given the requirement for a 2-day trip itinerary that focuses on history-oriented attractions, involves Vietnamese dining, and prioritizes accommodations known for safety, quality, and service, I need to gather relevant information in a structured manner.
# Action 1: AccommodationSearch[Expensive budget,[Good Safety, Good Quality, Good Service]]
# AccommodationSearch Expensive budget,[Good Safety, Good Quality, Good Service]
# Thought 2: I have gathered several accommodation options that meet the criteria of good safety, quality, and service. Next, I need to find suitable attractions that are history-oriented for the trip.
# Action 2: AttractionSearch[Expensive budget,[History Oriented]]
# AttractionSearch Expensive budget,[History Oriented]
# Thought 3: I've successfully gathered relevant information about accommodations, history-oriented attractions, and Vietnamese restaurants. Now, I need to find suitable Vietnamese dining options to complete the itinerary.
# Action 3: RestaurantSearch[Expensive budget, Vietnamese, [Good Flavor, Good Value]]
# RestaurantSearch Expensive budget, Vietnamese, [Good Flavor, Good Value]
# Thought 4: I have now gathered the necessary details about accommodations, history-oriented attractions, and Vietnamese dining options for the planned trip. With this information, I can now arrange a detailed itinerary that focuses on both convenience and enjoyment for the 2-day trip.
# Action 4: Planner[Generate a detailed travel itinerary for a 2-day trip with an expensive budget focusing on history-oriented attractions, including Vietnamese restaurants, and suggesting accommodations that prioritize good safety, quality, and service.]
# Planner Generate a detailed travel itinerary for a 2-day trip with an expensive budget focusing on history-oriented attractions, including Vietnamese restaurants, and suggesting accommodations that prioritize good safety, quality, and service.

# %%
def validate_restaurant_parameters_format(action_arg):
    pattern = r"(.*\s*.*),\s*(.*),\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, cuisine, preference list.")
    budget = match.group(1).lower()
    cuisine = match.group(2).lower()
    preference_list = match.group(3)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    #print(budget)
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget and expensive budget. Please try again.")

    cuisine_accepted = ["us","mexican","irish","french","italian","greek","indian","chinese","japanese","korean","vietnamese","thai","asian fusion","middle eastern"]
    #print(cuisine)
    cuisineInRange = False
    if cuisine in cuisine_accepted:
        cuisineInRange = True
    if not cuisineInRange:
        raise ValueError("Cuisine not valid. Accepted cuisine is: US / Mexican / Irish / French / Italian / Greek / Indian / Chinese / Japanese / Korean / Vietnamese / Thai / Asian Fusion and Middle Eastern. Please try again.")

    preference_list = [p.lower().strip() for p in preference_list.split(',')]
    preference_core = [p.strip().split(' ')[-1] for p in preference_list]
    print(preference_core)

    preferenceInRange = True
    preferenceAccepted = ['',"flavor","freshness","service","environment","value"]
    for p in preference_core:
        if p not in preferenceAccepted:
            preferenceInRange = False

    if not preferenceInRange:
        raise ValueError("Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.")    
    return True

# %%
validate_restaurant_parameters_format('Moderate Budget, Vietnamese, []')
# Out:
# ['']
# True
