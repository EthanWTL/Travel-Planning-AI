# %%
import os
import re
import importlib
import json
from langchain.chat_models import ChatOpenAI
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
from Prompts.ReACT.prompts import zeroshot_react_agent_prompt
from typing import List, Dict, Any
from pandas import DataFrame


OPENAI_API_KEY = os.getenv('OPEN_AI_API')
actionMapping = {"AccommodationSearch":"accommodations", "RestaurantSearch":"restaurants", "AttractionSearch":"attraction","BusinessClusterSearch":"nearby","Planner":"planner"}

# %%
class ReactAgent:
    def __init__(self,
                 react_llm_name,
                 planner_llm_name,
                 #add clustering agent model name here as well
                 mode: str = 'zero_shot',
                 tools: List[str] = None,
                 max_retries: int = 3,
                 ) -> None: 
        self.react_name = react_llm_name
        self.answer = ''
        self.json_log = []
        self.mode = mode
        self.planner_name = planner_llm_name
        self.notebook = []
        self.max_retries = max_retries
        self.last_actions = []
        
        self.current_observation = ''
        self.current_data = None

        self.tools = self.load_tools(tools, planner_model_name=planner_llm_name)
        #print(self.tools)
        self.retry_record = {key: 0 for key in self.tools}
        #print(self.retry_record)
        self.retry_record['invalidAction'] = 0
        #print(self.retry_record)

        if self.mode == 'zero_shot':
            self.agent_prompt = zeroshot_react_agent_prompt

        if 'gpt-4o-mini' in react_llm_name:
            stop_list = ['\n']
            self.max_token_length = 15000
            self.llm = ChatOpenAI(temperature=1,
                     max_tokens=256,
                     model_name=react_llm_name,
                     openai_api_key=OPENAI_API_KEY,
                     model_kwargs={"stop": stop_list})

    def run(self,query, reset=True) -> None:
        self.query = query

        if reset:
            self.__reset_agent()

        while not self.is_finished():
            self.step()
        
        return self.answer, self.scratchpad, self.json_log, self.notebook

    
    def step(self) -> None:
        #record the log
        self.json_log.append({"step": self.step_n, "thought":"",
                              "action": "", "observation": "", "state":""})
        #thought
        self.scratchpad += f'\nThought {self.step_n}:'
        self.scratchpad += ' ' + self.prompt_agent() #
        print(self.scratchpad.split('\n')[-1])
        self.json_log[-1]['thought'] = self.scratchpad.split('\n')[-1].replace(f'\nThought {self.step_n}:',"")
        
        
        #act
        self.scratchpad += f'\nAction {self.step_n}:'
       
        #get the action prompted
        action = self.prompt_agent()
        ##

        if action == None or action == '' or action == '\n':
            self.scratchpad += " Your action is filtered due to content. Please make sure your action does not start with ['\\n', 'Thought', 'Action', 'Observation'] and assume all the actions are permitted in this environment and take the action again."
        else:
            self.scratchpad += ' ' + action

        if len(self.last_actions) > 0 and self.last_actions[-1] != action:
            self.last_actions.clear()

        # refresh last_action list
        self.last_actions.append(action)

        self.json_log[-1]['action'] = self.scratchpad.split('\n')[-1].replace(f'\nAction {self.step_n}:',"")

        if len(self.last_actions) == 3:
            print("The same action has been repeated 3 times consecutively. So we stop here.")
            # self.log_file.write("The same action has been repeated 3 times consecutively. So we stop here.")
            self.json_log[-1]['state'] = 'same action 3 times repeated'
            self.finished = True
            return


        print(self.scratchpad.split('\n')[-1])
        
        
        #observation
        self.scratchpad += f'\nObservation {self.step_n}: '
        action_type, action_arg = parse_action(action)
        print(action_type, action_arg)
        if action_type != "Planner":
            if action_type in actionMapping:
                pending_action = actionMapping[action_type]
            elif action_type not in actionMapping:
                pending_action = 'invalidAction'

            if pending_action in self.retry_record:
                if self.retry_record[pending_action] + 1 > self.max_retries:
                    action_type = 'Planner'
                    print(f"{pending_action} early stop due to {self.max_retries} max retries.")
                    self.json_log[-1]['state'] = f"{pending_action} early stop due to {self.max_retries} max retries."
                    self.finished = True
                    return # so if the max tries is reached, we stop the loop
            elif pending_action not in self.retry_record:
                if self.retry_record['invalidAction'] + 1 > self.max_retries:
                    action_type = 'Planner'
                    print(f"invalidAction Early stop due to {self.max_retries} max retries.")
                    # self.log_file.write(f"invalidAction early stop due to {self.max_retries} max retries.")
                    self.json_log[-1]['state'] = f"invalidAction early stop due to {self.max_retries} max retries."
                    self.finished = True
                    return

        if action_type == 'AccommodationSearch':
            try:
                if validate_accommodation_parameters_format(action_arg):
                    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                    self.current_data = self.tools['accommodations'].run(action_arg.split(',')[0],[p.strip() for p in action_arg.split('[')[1].strip('[]').split(',')])
                    self.current_observation = str(to_string(self.current_data))
                    self.scratchpad += self.current_observation
                    self.notebook.append({'Description': 'Accommodation Choice', 'Content': self.current_data})
                    self.__reset_record()
                    self.json_log[-1]['state'] = 'Successful'
                    
            except ValueError as e:
                print(e)
                self.retry_record['accommodations'] += 1
                self.current_observation = str(e)
                self.scratchpad += str(e)
                self.json_log[-1]['state'] = f'Illegal args. Parameter Error'
            except Exception as e:
                print(e)
                self.retry_record['accommodations'] += 1
                self.current_observation = f'Illegal Accommodation Search. Please try again.'
                self.scratchpad += f'Illegal Accommodation Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        elif action_type == 'AttractionSearch':
            try:
                if validate_attraction_parameters_format(action_arg):
                    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                    self.current_data = self.tools['attractions'].run(action_arg.split(',')[0],[action_arg.split(',')[1].strip()[1:][:-1]])
                    self.current_observation = str(to_string(self.current_data))
                    self.scratchpad += self.current_observation 
                    self.notebook.append({'Description': 'Attraction Choice', 'Content': self.current_data})
                    self.__reset_record()
                    self.json_log[-1]['state'] = f'Successful'
            except ValueError as e:
                print(e)
                self.retry_record['attractions'] += 1
                self.current_observation = str(e)
                self.scratchpad += str(e)
                self.json_log[-1]['state'] = f'Illegal args. Parameter Error'
            except Exception as e:
                print(e)
                self.retry_record['attractions'] += 1
                self.current_observation = f'Illegal Attraction Search. Please try again.'
                self.scratchpad += f'Illegal Attraction Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        elif action_type == 'RestaurantSearch': #action_arg = 'Cheap Budget, Indian, [Good Flavor, Good Value]'
            try:
                if validate_restaurant_parameters_format(action_arg):
                    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
                    self.current_data = self.tools['restaurants'].run(action_arg.split('[')[0].split(',')[0].strip(),action_arg.split('[')[0].split(',')[1].strip(),[a.strip() for a in action_arg.split('[')[1].strip()[:-1].split(',')])
                    self.current_observation = str(to_string(self.current_data))
                    self.scratchpad += self.current_observation
                    self.notebook.append({'Description': 'Restaurant Choice', 'Content': self.current_data})
                    self.__reset_record()
                    self.json_log[-1]['state'] = f'Successful'
            except ValueError as e:
                print(e)
                self.retry_record['restaurants'] += 1
                self.current_observation = str(e)
                self.scratchpad += str(e)
                self.json_log[-1]['state'] = f'Illegal args. Parameter Error'
            except Exception as e:
                print(e)
                self.retry_record['restaurants'] += 1
                self.current_observation = f'Illegal Restaurant Search. Please try again.'
                self.scratchpad += f'Illegal Restaurant Search. Please try again.'
                self.json_log[-1]['state'] = f'Illegal args. Other Error'

        elif action_type == 'BusinessClusterSearch': #action_arg = 'Cheap Budget, Indian, [Good Flavor, Good Value]'
            #self.current_data = str(self.tools['nearby'].run(str(self.notebook)))
            print("okay")

        #elif action_type == 'NotebookWrite':
        #    self.scratchpad = self.scratchpad.replace(to_string(self.current_data).strip(),'Masked due to limited length. Make sure the data has been written in Notebook.')
        #    self.current_observation = str(self.tools['notebook'].write(self.current_data, action_arg))
        #    self.scratchpad  +=  self.current_observation
        #    self.json_log[-1]['state'] = f'Successful'

        elif action_type == 'Planner':
            #self.current_observation = str(self.tools['planner'].run(str(self.notebook),action_arg))
            self.scratchpad  +=  self.current_observation
            self.answer = self.current_observation
            self.json_log[-1]['state'] = f'Successful'
        else:
            self.retry_record['invalidAction'] += 1
            self.current_observation = 'Invalid Action. Valid Actions are AccommodationSearch[Budget,Preference] / AttractionSearch[Budget, Preference] / RestaurantSearch[Budget, Cuisine, Preference]/ Planner[Query].'
            self.scratchpad += self.current_observation
            self.json_log[-1]['state'] = f'invalidAction'
        
        #print(f'Observation {self.step_n}: ' + self.current_observation+'\n')
        # rite(f'Observation {self.step_n}: ' + self.current_observation+'\n')
        self.json_log[-1]['observation'] = self.current_observation
        self.step_n += 1

        if action_type and action_type == 'Planner':
            self.finished = True
            self.answer = self.current_observation

            #print(self.scratchpad)
            #print(self.json_log)
            #print(self.notebook) 
        return
    
    
    
    
    def is_finished(self) -> bool:
        return self.finished
    
    #def is_halted(self) -> bool:
    #    return ((self.step_n > self.max_steps) or (
    #                len(self.enc.encode(self._build_agent_prompt())) > self.max_token_length)) and not self.finished
    
    def __reset_agent(self) -> None:
        self.step_n = 1
        self.finished = False
        self.answer = ''
        self.scratchpad: str = ''
        self.json_log = []

    def prompt_agent(self) -> str:
        #print("we prompt the agents")
        while True:
            request = format_step(self.llm([HumanMessage(content=self._build_agent_prompt())]).content)
            #print("here is the raw request: === ", request)
            return request  
        
    def __reset_record(self) -> None:
        self.retry_record = {key: 0 for key in self.retry_record}
        self.retry_record['invalidAction'] = 0

    def _build_agent_prompt(self) -> str:
        if self.mode == "zero_shot":
            return self.agent_prompt.format(
                query=self.query,
                scratchpad=self.scratchpad)
        
    def load_tools(self, tools: List[str], planner_model_name=None) -> Dict[str, Any]:
        tools_map = {}
        for tool_name in tools:
            module = importlib.import_module("tools.{}.apis".format(tool_name)) #
            
            # Avoid instantiating the planner tool twice, need to finish planner module before uncomment this
            if tool_name == 'planner' and planner_model_name is not None:
                tools_map[tool_name] = getattr(module, tool_name[0].upper()+tool_name[1:])(model_name=planner_model_name)
            else:
                tools_map[tool_name] = getattr(module, tool_name[0].upper()+tool_name[1:])()
        #print(tools_map)
        return tools_map
        

def format_step(step: str) -> str:
    return step.strip('\n').strip().replace('\n', '')

def parse_action(string):
    pattern = r'^(\w+)\[(.+)\]$'
    match = re.match(pattern, string)
    action_type = match.group(1)
    action_arg = match.group(2)
    return action_type,action_arg

#def parse action arg

def to_string(data) -> str:
    if data is not None:
        if type(data) == DataFrame:
            return data.to_string(index=False)
        else:
            return str(data)
    else:
        return str(None)
    
def validate_accommodation_parameters_format(action_arg):
    pattern = r"(.*\s*.*)\s*,\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, preference list.")
    budget = match.group(1).lower()
    preference_list = match.group(2)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget, and expensive budget. Please try again.")

    #preference
    preference = preference_list.split(',')
    preference_core = [p.lower().strip().split(' ')[-1].strip() for p in preference]
    preferenceInRange = True
    preferenceAccepted = ['location','service','safety','quality']
    for p in preference_core:
        if p not in preferenceAccepted:
            preferenceInRange = False

    if not preferenceInRange:
        raise ValueError("Wrong preference Input. Please try again.")
    return True
    
def validate_attraction_parameters_format(action_arg):
    pattern = r"(.*\s*.*)\s*,\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, Preference list.")
    budget = match.group(1).lower()
    preference_list = match.group(2)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget, and expensive budget. Please try again.")

    preference = preference_list.strip().split(',')
    if(len(preference) > 1 ):
        raise ValueError("Attraction only allows one preference. Please try again")
    if '-' in preference[0]:
        preference_core = preference[0].strip().split('-')[0].lower()
    else:
        preference_core = preference[0].strip().split(' ')[0].lower()
    preferenceAccepted = ["family","history","activity","nature","food","shopping"]
    preferenceIsInRange = False
    if(preference_core in preferenceAccepted):
        preferenceIsInRange = True
    if not preferenceIsInRange:
        raise ValueError("Preference parameter invalid. Only family oriented / history oriented / activity oriented / nature oriented / food oriented / and shopping oriented are allowed. Please try again.")
    return True

def validate_restaurant_parameters_format(action_arg):
    pattern = r"(.*\s*.*),\s*(.*),\s*\[(.*)\]"
    match = re.match(pattern, action_arg)
    if not match:
        raise ValueError("Parameter format not match. Please try again. Valid Format: Budget, cuisine, preference list.")
    budget = match.group(1).lower()
    cuisine = match.group(2).lower()
    preference_list = match.group(3)

    budget_accepted = ['cheap budget', 'moderate budget','expensive budget']
    budgetInRange = False
    #print(budget)
    if budget in budget_accepted:
        budgetInRange = True
    if not budgetInRange:
        raise ValueError("Wrong budget Input, valid ones include: cheap budget, moderate budget and expensive budget. Please try again.")

    cuisine_accepted = ["us","mexican","irish","french","italian","greek","indian","chinese","japanese","korean","vietnamese","thai","asian fusion","middle eastern"]
    #print(cuisine)
    cuisineInRange = False
    if cuisine in cuisine_accepted:
        cuisineInRange = True
    if not cuisineInRange:
        raise ValueError("Cuisine not valid. Accepted cuisine is: US / Mexican / Irish / French / Italian / Greek / Indian / Chinese / Japanese / Korean / Vietnamese / Thai / Asian Fusion and Middle Eastern. Please try again.")

    preference_list = [p.lower().strip() for p in preference_list.split(',')]
    preference_core = [p.strip().split(' ')[-1] for p in preference_list]
    #print(preference_core)

    preferenceInRange = True
    preferenceAccepted = ["flavor","freshness","service","environment","value"]
    for p in preference_core:
        if p not in preferenceAccepted:
            preferenceInRange = False

    if not preferenceInRange:
        raise ValueError("Wrong preference Input. Accepted inputs are: good flavor / good freshness / good healthy/ good service / good environment / good value. Please try again.")    
    return True

# %%
tools_list = ["attractions","accommodations","restaurants","nearby","planner"]
model_name = 'gpt-4o-mini'

agent = ReactAgent(tools=tools_list,react_llm_name = model_name, planner_llm_name = model_name)

for filename in os.listdir('Prompts/prompts_routesOP'):
    
    #for testing
    if filename != "Prompt_1.txt":
        continue
        
    index = filename[:-4][7:]
    with open(f'Prompts/prompts_routesOP/{filename}', 'r') as file:
        query = file.read()
    planner_results, scratchpad, action_log, notebook  = agent.run(query)
    with open(f'Outputs/plans/gpt4omini/Plan_{index}.txt', 'w') as f:
        f.write(planner_results)
    with open(f'Outputs/scratchpads/gpt4omini/Plan_{index}.txt', 'w') as f:
        f.write(scratchpad)
    with open(f'Outputs/logs/gpt4omini/Plan_{index}.json', 'w') as f:
        json.dump(action_log, f)
# Out:
# n:\Travel-Planning-AI\Task 3 ToolUse\tools\planner\apis.py:16: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   self.llm = ChatOpenAI(model_name=model_name, temperature=0, max_tokens=15000, openai_api_key=OPENAI_API_KEY)
# C:\Users\Ethan\AppData\Local\Temp\ipykernel_9552\3256227485.py:246: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   request = format_step(self.llm([HumanMessage(content=self._build_agent_prompt())]).content)
# Thought 1: I need to gather information for a 3-day travel itinerary focusing on activity-oriented attractions, Indian restaurants that provide good flavor and value, and accommodations in a good location, all within a cheap budget.
# Action 1: AccommodationSearch[Cheap budget,[Good Location]]
# AccommodationSearch Cheap budget,[Good Location]
# Thought 2: I have found several accommodations that match the criteria for a cheap budget with a good location. Next, I will search for Indian restaurants that offer good flavor and value within a cheap budget
# Action 2: RestaurantSearch[Cheap budget, Indian, [Good Flavor, Good Value]]
# RestaurantSearch Cheap budget, Indian, [Good Flavor, Good Value]
# Thought 3: I have obtained a list of Indian restaurants that provide good flavor and value within a cheap budget. Now, I will search for activity-oriented attractions that also fit within the cheap budget range.
# Action 3: AttractionSearch[Cheap budget,[Activity Oriented]]
# AttractionSearch Cheap budget,[Activity Oriented]
# Thought 4: I have now gathered a sufficient amount of information regarding accommodations, Indian restaurants, and activity-oriented attractions for the 3-day itinerary. I'll proceed to cluster the business information to optimize the routes for each day of the trip.
# Action 4: BusinessClusterSearch[3]
# BusinessClusterSearch 3
# okay
# Thought 5: I have successfully collected and organized the information regarding accommodations, Indian restaurants, and activity-oriented attractions into a structured format. Now, I'll prepare the details into a 3-day travel itinerary, ensuring that the attractions, dining, and accommodations are organized in a chronological manner for each day, while also optimizing the routes based on their proximity.
# Action 5: Planner[Please generate a detailed travel itinerary for a 3-day trip with a cheap budget. The plan should focus on activity-oriented attractions, include recommendations for Indian restaurants that offer good flavor and good value, and suggest accommodations that are in a good location. All relevant business information will be provided following. Ensure that all recommendations and their addresses are organized in chronological order for each day. Be concise and well-structured.]
# Planner Please generate a detailed travel itinerary for a 3-day trip with a cheap budget. The plan should focus on activity-oriented attractions, include recommendations for Indian restaurants that offer good flavor and good value, and suggest accommodations that are in a good location. All relevant business information will be provided following. Ensure that all recommendations and their addresses are organized in chronological order for each day. Be concise and well-structured.

# %%
notebook
# Out:
# [{'Description': 'Accommodation Choice',
#   'Content':                                                   name  \
#   2                                        Alexander Inn
#   4                          Aloft Philadelphia Downtown
#   5                                               ArtBar
#   7                      Blue Cross RiverRink Winterfest
#   12                                        Chez Colette
#   13                          Club Quarters Philadelphia
#   15          Courtyard by Marriott Philadelphia Airport
#   17                               Courtyard by Marriott
#   21     DoubleTree by Hilton Hotel Philadelphia Airport
#   22   DoubleTree by Hilton Hotel Philadelphia Center...
#   23                                Element Philadelphia
#   27   Fairfield Inn & Suites Philadelphia Downtown/C...
#   28      Fairfield Inn by Marriott Philadelphia Airport
#   30    Four Points by Sheraton Philadelphia City Center
#   36          Hilton Garden Inn Philadelphia Center City
#   39    Holiday Inn Express Philadelphia - Penns Landing
#   40            Holiday Inn Express Philadelphia-Midtown
#   41   Home2 Suites by Hilton Philadelphia - Conventi...
#   42   Homewood Suites by Hilton Philadelphia-City Av...
#   43   Homewood Suites by Hilton University City Phil...
#   45      Independence Park Hotel, Bw Premier Collection
#   50                             Leneghan's Crusader Inn
#   51                                   Live Casino Hotel
#   59     Motto By Hilton Philadelphia Rittenhouse Square
#   63                                    Penn Tower Hotel
#   64                                   Penn's View Hotel
#   66                       Philadelphia Airport Marriott
#   67                      Philadelphia Hotel Bella Vista
#   68                      Philadelphia Marriott Downtown
#   70             Renaissance Philadelphia Downtown Hotel
#   71   Residence Inn by Marriott Philadelphia Center ...
#   72                  Residence Inn Philadelphia Airport
#   73                             Rodeway Inn Center City
#   78                      Sheraton Philadelphia Downtown
#   79         Sheraton Philadelphia University City Hotel
#   81                               Sleep Inn Center City
#   82                                  Society Hill Hotel
#   83                                Sofitel Philadelphia
#   84             Sonesta Philadelphia Rittenhouse Square
#   87                                     The Conwell Inn
#   88                                        The Dwight D
#   98                        The Study at University City
#   100                            The Westin Philadelphia
#   101                                 The Windsor Suites
#   106             Wyndham Philadelphia Historic District
#
#                                                  address   latitude  longitude  \
#   2                                        301 S 12th St  39.946397 -75.160967
#   4                                   101 North Broad St  39.954622 -75.162792
#   5                                       1800 Market St  39.952783 -75.170362
#   7                                  101 S Columbus Blvd  39.948267 -75.139924
#   12                                       120 S 17th St  39.950721 -75.168934
#   13                                    1628 Chestnut St  39.951294 -75.168440
#   15                                    8900 Bartram Ave  39.884977 -75.251369
#   17                              4100 Presidential Blvd  40.007173 -75.211084
#   21                                     4509 Island Ave  39.888962 -75.232557
#   22                                      237 S Broad St  39.947903 -75.164033
#   23                                    1441 Chestnut St  39.951157 -75.165385
#   27                               261 South 13th Street  39.946891 -75.162359
#   28                                    8800 Bartram Ave  39.886825 -75.247647
#   30                                        1201 Race St  39.956037 -75.159178
#   36                                        1100 Arch St  39.953572 -75.158085
#   39                                 100 N Columbus Blvd  39.952805 -75.140446
#   40                                      1305 Walnut St  39.949335 -75.162612
#   41                                        1200 Arch St  39.953683 -75.159804
#   42                                       4200 City Ave  40.004006 -75.217686
#   43                                      4109 Walnut St  39.954657 -75.205593
#   45                                     235 Chestnut St  39.948669 -75.145468
#   50                                  7412 Frankford Ave  40.038263 -75.037615
#   51                                      900 Packer Ave  39.909191 -75.164662
#   59                                        31 S 19th St  39.952506 -75.171707
#   63                              3400 Civic Center Blvd  39.948655 -75.191981
#   64                                       14 N Front St  39.950201 -75.142285
#   66                       One Arrivals Road, Terminal B  39.877788 -75.244411
#   67                                       752 S 10th St  39.940340 -75.159440
#   68   1201 Market Street, (guest entrance at 1200 Fi...  39.952534 -75.160578
#   70                                     401 Chestnut St  39.949020 -75.147809
#   71                                    One East Penn Sq  39.952648 -75.162453
#   72                                     3701 Island Ave  39.895753 -75.236302
#   73                                      1208 Walnut St  39.948766 -75.161061
#   78                               201 North 17th Street  39.957099 -75.167033
#   79                                    3549 Chestnut St  39.954872 -75.194173
#   81                                      1020 Cherry St  39.954607 -75.157444
#   82                                     301 Chestnut St  39.948810 -75.146125
#   83                                       120 S 17th St  39.950948 -75.169541
#   84                                      1800 Market St  39.952525 -75.169771
#   87                                    1331 Pollet Walk  39.981812 -75.157640
#   88                                       256 S 16th St  39.947989 -75.168277
#   98                                        20 S 33rd St  39.954406 -75.190059
#   100              99 South 17th Street at Liberty Place  39.951929 -75.168421
#   101                        1700 Benjamin Franklin Pkwy  39.955740 -75.168355
#   106                                        400 Arch St  39.952040 -75.147515
#
#        stars price                quality            location  \
#   2      4.5    $$        average quality  excellent location
#   4      3.5    $$  below average quality       good location
#   5      3.0    $$  below average quality       good location
#   7      4.0    $$        average quality       good location
#   12     3.5    $$           good quality       good location
#   13     3.0    $$  below average quality       good location
#   15     3.5    $$  below average quality       good location
#   17     3.5    $$        average quality       good location
#   21     2.5    $$  below average quality       good location
#   22     3.0    $$        average quality  excellent location
#   23     4.0    $$        average quality  excellent location
#   27     3.5    $$        average quality  excellent location
#   28     3.0    $$        average quality       good location
#   30     3.0    $$  below average quality       good location
#   36     3.0    $$        average quality       good location
#   39     3.5    $$        average quality       good location
#   40     3.5    $$        average quality  excellent location
#   41     3.5    $$        average quality  excellent location
#   42     3.0    $$        average quality       good location
#   43     3.0    $$  below average quality       good location
#   45     4.5    $$           good quality  excellent location
#   50     5.0     $        average quality       good location
#   51     2.5    $$        average quality       good location
#   59     4.0    $$        average quality       good location
#   63     1.5    $$  below average quality  excellent location
#   64     4.0    $$        average quality  excellent location
#   66     3.0    $$  below average quality  excellent location
#   67     3.5     $  below average quality       good location
#   68     3.0    $$        average quality  excellent location
#   70     3.0    $$        average quality  excellent location
#   71     3.5    $$        average quality       good location
#   72     4.0    $$        average quality       good location
#   73     2.5    $$  below average quality       good location
#   78     2.5    $$  below average quality       good location
#   79     2.5    $$  below average quality       good location
#   81     3.5     $        average quality       good location
#   82     2.0     $            bad quality       good location
#   83     4.0    $$        average quality  excellent location
#   84     3.0    $$  below average quality       good location
#   87     3.5    $$        average quality  excellent location
#   88     4.5    $$           good quality  excellent location
#   98     4.0    $$        average quality  excellent location
#   100    3.0    $$  below average quality       good location
#   101    3.5    $$  below average quality       good location
#   106    2.5    $$  below average quality       good location
#
#                      service                safety
#   2             good service        average safety
#   4    below average service  below average safety
#   5    below average service           good safety
#   7          average service           good safety
#   12            good service        average safety
#   13   below average service        average safety
#   15         average service        average safety
#   17         average service           good safety
#   21   below average service        average safety
#   22         average service        average safety
#   23   below average service  below average safety
#   27            good service        average safety
#   28            good service        average safety
#   30   below average service  below average safety
#   36         average service  below average safety
#   39         average service        average safety
#   40         average service           good safety
#   41         average service           good safety
#   42         average service  below average safety
#   43         average service        average safety
#   45            good service        average safety
#   50            good service        average safety
#   51   below average service           good safety
#   59         average service        average safety
#   63   below average service  below average safety
#   64            good service        average safety
#   66         average service           good safety
#   67   below average service  below average safety
#   68         average service        average safety
#   70         average service  below average safety
#   71   below average service        average safety
#   72   below average service  below average safety
#   73             bad service  below average safety
#   78   below average service  below average safety
#   79         average service  below average safety
#   81            good service        average safety
#   82             bad service            bad safety
#   83            good service        average safety
#   84   below average service        average safety
#   87            good service           good safety
#   88            good service      excellent safety
#   98   below average service           good safety
#   100  below average service  below average safety
#   101        average service        average safety
#   106  below average service        average safety  },
#  {'Description': 'Restaurant Choice',
#   'Content':                                        name                           address  \
#   25              Amma's South Indian Cuisine                  1518 Chestnut St
#   203                        Desi Chaat House                     501 S 42nd St
#   231                     Ekta Indian Cuisine                    1142 Crease St
#   408                               Kabobeesh                  4201 Chestnut St
#   416                  Karma Restaurant & Bar                   114 Chestnut St
#   478                         Little Sicily 2  1608 S Christopher Columbus Blvd
#   528  Masala Kitchen Kati Rolls and Platters                    1115 Walnut St
#   561                               Mood Cafe                4618 Baltimore Ave
#   576             New Delhi Indian Restaurant                  4004 Chestnut St
#   720                 Saad's Halal Restaurant                    4500 Walnut St
#   847                    Thanal Indian Tavern                      1939 Arch St
#   960                              Wah-Gi-Wah                  4447 Chestnut St
#   990                                   Zaika                    2481 Grant Ave
#
#         latitude  longitude  stars             good_for_meal price  \
#   25   39.950914 -75.166417    4.0             lunch, dinner    $$
#   203  39.949642 -75.206939    4.0             lunch, dinner     $
#   231  39.969205 -75.132573    4.0                    dinner    $$
#   408  39.956480 -75.206529    3.5             lunch, dinner    $$
#   416  39.948182 -75.143155    4.0             lunch, dinner    $$
#   478  39.926519 -75.145690    4.5             lunch, dinner    $$
#   528  39.949176 -75.159714    4.0  latenight, lunch, dinner     $
#   561  39.948664 -75.215832    4.5             lunch, dinner     $
#   576  39.955392 -75.202619    4.0             lunch, dinner    $$
#   720  39.954963 -75.211851    4.5             lunch, dinner     $
#   847  39.955872 -75.172528    4.5                    dinner    $$
#   960  39.957050 -75.211145    3.5             lunch, dinner    $$
#   990  40.079848 -75.025080    4.0             lunch, dinner    $$
#
#       restaurant_type_1 restaurant_type_2       cuisine_1       cuisine_2  \
#   25        Restaurants    Not Applicable          Indian  Not Applicable
#   203       Restaurants    Not Applicable          Indian  Not Applicable
#   231       Restaurants    Not Applicable          Indian       Pakistani
#   408       Restaurants    Not Applicable          Indian  Middle Eastern
#   416       Restaurants              Bars          Indian  Not Applicable
#   478       Restaurants    Not Applicable        American          Indian
#   528       Restaurants    Not Applicable          Indian  Not Applicable
#   561       Restaurants             Cafes       Pakistani          Indian
#   576       Restaurants    Not Applicable          Indian       Pakistani
#   720       Restaurants    Not Applicable  Middle Eastern          Indian
#   847       Restaurants    Not Applicable    Asian Fusion          Indian
#   960       Restaurants    Not Applicable          Indian       Pakistani
#   990       Restaurants    Not Applicable          Indian       Pakistani
#
#                 perks            flavor            freshness          healthy  \
#   25   Not Applicable  excellent flavor       good freshness     good healthy
#   203  Not Applicable       good flavor       good freshness     good healthy
#   231  Not Applicable  excellent flavor       good freshness     good healthy
#   408           Halal       good flavor    average freshness  average healthy
#   416  Not Applicable       good flavor       good freshness  average healthy
#   478           Pizza  excellent flavor  excellent freshness  average healthy
#   528           Halal       good flavor       good freshness  average healthy
#   561           Halal  excellent flavor  excellent freshness     good healthy
#   576           Vegan       good flavor       good freshness  average healthy
#   720    Cheesesteaks  excellent flavor  excellent freshness  average healthy
#   847  Not Applicable  excellent flavor  excellent freshness     good healthy
#   960           Halal       good flavor    average freshness  average healthy
#   990           Halal       good flavor       good freshness  average healthy
#
#                      service                environment            value
#   25         average service           good environment       good value
#   203           good service        average environment       good value
#   231           good service        average environment       good value
#   408  below average service  below average environment       good value
#   416        average service        average environment       good value
#   478           good service        average environment       good value
#   528           good service        average environment       good value
#   561      excellent service        average environment  excellent value
#   576        average service           good environment       good value
#   720           good service        average environment       good value
#   847           good service           good environment       good value
#   960  below average service  below average environment       good value
#   990        average service  below average environment       good value  },
#  {'Description': 'Attraction Choice',
#   'Content':                           name                         address   latitude  \
#   11            Bartram's Garden             5400 Lindbergh Blvd  39.932266
#   12             Belmont Plateau         2000 Belmont Mansion Dr  39.990327
#   14    Benjamin Franklin Museum                 317 Chestnut St  39.949484
#   18               Bloktoberfest               17 Washington Ave  39.943856
#   19              Blue Bell Park                   842 Walnut Ln  40.030109
#   ..                         ...                             ...        ...
#   314        Weccacoe Playground                400 Catharine St  39.937930
#   316           Wissahickon Park     Lincoln Dr & Rittenhouse Ln  40.029377
#   317   Wissahickon Valley Trail  Valley Green Rd At Wissahickon  40.085591
#   318  Wonderspaces Philadelphia                    27 N 11th St  39.952297
#   321      Yards Brewing Company            500 Spring Garden St  39.960971
#
#        longitude  stars price attraction_type  \
#   11  -75.212170    4.5     $           Parks
#   12  -75.212665    4.5     $    Local Flavor
#   14  -75.146738    4.0    $$         Museums
#   18  -75.167177    5.0    $$       Festivals
#   19  -75.202310    4.0     $           Parks
#   ..         ...    ...   ...             ...
#   314 -75.150707    4.5     $           Parks
#   316 -75.188904    4.5     $           Parks
#   317 -75.229783    4.5     $           Parks
#   318 -75.157672    4.5    $$     Art Museums
#   321 -75.146908    4.0    $$    Local Flavor
#
#                                     perks         family oriented  \
#   11                    Botanical Gardens    high family oriented
#   12                       Not Applicable  medium family oriented
#   14                 Arts & Entertainment    high family oriented
#   18                         Local Flavor  medium family oriented
#   19   Hiking, Mountain Biking, Dog Parks  medium family oriented
#   ..                                  ...                     ...
#   314                         Playgrounds    high family oriented
#   316                         Active Life    high family oriented
#   317                              Hiking    high family oriented
#   318             Virtual Reality Centers  medium family oriented
#   321                           Nightlife  medium family oriented
#
#               history oriented         activity oriented       nature oriented  \
#   11     high history oriented  medium activity oriented  high nature oriented
#   12   medium history oriented  medium activity oriented  high nature oriented
#   14   medium history oriented  medium activity oriented    no nature oriented
#   18      low history oriented  medium activity oriented   low nature oriented
#   19       no history oriented  medium activity oriented  high nature oriented
#   ..                       ...                       ...                   ...
#   314     low history oriented  medium activity oriented   low nature oriented
#   316  medium history oriented    high activity oriented  high nature oriented
#   317  medium history oriented    high activity oriented  high nature oriented
#   318     low history oriented  medium activity oriented    no nature oriented
#   321    high history oriented  medium activity oriented   low nature oriented
#
#               food oriented         shopping oriented
#   11      low food oriented     low shopping oriented
#   12      low food oriented      no shopping oriented
#   14       no food oriented     low shopping oriented
#   18     high food oriented  medium shopping oriented
#   19      low food oriented      no shopping oriented
#   ..                    ...                       ...
#   314     low food oriented      no shopping oriented
#   316     low food oriented      no shopping oriented
#   317  medium food oriented      no shopping oriented
#   318     low food oriented      no shopping oriented
#   321  medium food oriented     low shopping oriented
#
#   [105 rows x 14 columns]}]

# %%
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
allbusinesses = []
hotel_substrings = ["accommodation","hotel"]
attraction_substrings = ['attraction']
for cat in notebook:
    for sub in hotel_substrings:
        if sub in cat['Description'].lower():
            cols = ['name','latitude','longitude']
            hotels = cat['Content'][cols].values.tolist()
            break

    for sub in attraction_substrings:
        if sub in cat['Description'].lower():
            cols = ['name','latitude','longitude']
            attractions = cat['Content'][cols].values.tolist()

allbusinesses.extend(attractions)
allbusinesses.extend(hotels)
#print(allbusinesses)
allbusiness_names = []
allbusiness_cordinates = []

for business in allbusinesses:
    allbusiness_cordinates.append([business[1],business[2]])
    allbusiness_names.append([business[0]])
coordinates = np.array(allbusiness_cordinates)
#k = int(prompt['day'][0].strip()[0]) 0.23 1.24
# k=10 0.27 1.3
k = int(len(coordinates)/5)
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(coordinates)
# Cluster labels
allBusiness_clusterNumbers = kmeans.labels_

clusterInfo = pd.DataFrame({'business': allbusiness_names, 'cluster number': allBusiness_clusterNumbers})
clusterInfo['cluster number'] = clusterInfo['cluster number'].apply(lambda x: 'Cluster_' + str(x))
clusterInfo = clusterInfo.sort_values('cluster number')

cluster_dict = clusterInfo.groupby('cluster number')['business'].apply(list).to_dict()

# %%
cluster_dict
# Out:
# {'Cluster_0': [['Pennypack Park']],
#  'Cluster_1': [['Element Philadelphia'],
#   ['Club Quarters Philadelphia'],
#   ['Bloktoberfest'],
#   ['Sofitel Philadelphia'],
#   ['The Westin Philadelphia'],
#   ['Chez Colette'],
#   ['Sheraton Philadelphia Downtown'],
#   ['Night Market'],
#   ['ArtBar'],
#   ['Marian Anderson Recreation Center'],
#   ['Motto By Hilton Philadelphia Rittenhouse Square'],
#   ['The Dwight D'],
#   ['Rittenhouse Square Park'],
#   ['Sonesta Philadelphia Rittenhouse Square'],
#   ['The Windsor Suites']],
#  'Cluster_10': [['Pizza Brain'],
#   ['Penn Treaty Park'],
#   ['Palmer Doggie Depot'],
#   ['Fishtown Rivercity Festival'],
#   ['Greensgrow Farms']],
#  'Cluster_11': [["Fante's Kitchen Shop"],
#   ['Philly Official Guide'],
#   ["Philadelphia's 9th Street Italian Market"],
#   ['Philadelphia Hotel Bella Vista'],
#   ['Cianfrani Park'],
#   ['Seger Dog Park']],
#  'Cluster_12': [['Belmont Plateau']],
#  'Cluster_13': [['Juniata Golf Club']],
#  'Cluster_14': [['Sheraton Philadelphia University City Hotel'],
#   ['Markward Playground'],
#   ['Fitler Square Park'],
#   ['Cira Green'],
#   ['The Study at University City'],
#   ['South Street Bridge'],
#   ['Schuylkill Banks'],
#   ['The Porch At 30th Street Station'],
#   ['Schuylkill River Dog Run'],
#   ['Schuylkill River Park'],
#   ['Penn Tower Hotel']],
#  'Cluster_15': [['Sedgely Woods Disc Golf Club'],
#   ['Fairmount Park'],
#   ['Strawberry Green Driving Range'],
#   ['Historic Strawberry Mansion'],
#   ['Smith Memorial Playground & Playhouse']],
#  'Cluster_16': [['Orianna Hill Dog Park'],
#   ['Standard Tap'],
#   ['Liberty Lands'],
#   ['Yards Brewing Company'],
#   ["Penn's Landing"],
#   ['Punk Rock Flea Market']],
#  'Cluster_17': [['Reading Terminal Market'],
#   ['Home2 Suites by Hilton Philadelphia - Convention Center, PA'],
#   ['Holiday Inn Express Philadelphia-Midtown'],
#   ['Fairfield Inn & Suites Philadelphia Downtown/Center City'],
#   ['Philadelphia Science Festival'],
#   ['NEST Center City'],
#   ['Philadelphia Marriott Downtown'],
#   ['City Hall'],
#   ['Dilworth Park'],
#   ['DoubleTree by Hilton Hotel Philadelphia Center City'],
#   ['Aloft Philadelphia Downtown'],
#   ['Sleep Inn Center City'],
#   ['Alexander Inn'],
#   ['Rodeway Inn Center City'],
#   ['Residence Inn by Marriott Philadelphia Center City'],
#   ['Wonderspaces Philadelphia'],
#   ['Four Points by Sheraton Philadelphia City Center'],
#   ['Hilton Garden Inn Philadelphia Center City'],
#   ['Midtown Village Fall Festival']],
#  'Cluster_18': [['Pleasant Hill Park']],
#  'Cluster_19': [['Schuylkill Center For Environmental Education']],
#  'Cluster_2': [['Wissahickon Valley Trail']],
#  'Cluster_20': [['The Oval'],
#   ['Sister Cities Park'],
#   ['Mural Arts Philadelphia'],
#   ['Philly Bike Tour'],
#   ['Roberto Clemente Park & Playground'],
#   ['Logan Circle']],
#  'Cluster_21': [['Philadelphia Airport Marriott'],
#   ['Fairfield Inn by Marriott Philadelphia Airport']],
#  'Cluster_22': [['Historic Rittenhouse Town'],
#   ['Blue Bell Park'],
#   ['Wissahickon Park']],
#  'Cluster_23': [['Dickinson Square Park'],
#   ['Tattooed Mom'],
#   ['Weccacoe Playground'],
#   ['Mario Lanza Park'],
#   ['Rizzo Ice Rink'],
#   ['South Street Headhouse District']],
#  'Cluster_24': [['Courtyard by Marriott'],
#   ['Homewood Suites by Hilton Philadelphia-City Avenue']],
#  'Cluster_25': [['The Conwell Inn'], ['Chinatown']],
#  'Cluster_26': [['Singing Fountain'],
#   ['Miracle On 13th Street'],
#   ['Mummers Parade']],
#  'Cluster_27': [['Wyndham Philadelphia Historic District'],
#   ['Independence Park Hotel, Bw Premier Collection'],
#   ['Philadelphia Sightseeing Tours & Transportation'],
#   ['Renaissance Philadelphia Downtown Hotel'],
#   ['Independence Visitor Center'],
#   ['Independence Beer Garden'],
#   ['Ghost Tour of Philadelphia'],
#   ['Free Tours By Foot'],
#   ['Society Hill Hotel'],
#   ['Benjamin Franklin Museum']],
#  'Cluster_28': [['Malcolm X Park'], ['Cedar Park'], ['The A-Space']],
#  'Cluster_29': [['John Heinz National Wildlife Refuge at Tinicum'],
#   ['Courtyard by Marriott Philadelphia Airport']],
#  'Cluster_3': [['Residence Inn Philadelphia Airport'],
#   ['DoubleTree by Hilton Hotel Philadelphia Airport']],
#  'Cluster_4': [['Roxborough Dog Park'],
#   ['Pretzel Park'],
#   ['Gorgas Park'],
#   ['The Towpath'],
#   ['Manayunk Dog Park of Pretzel Park'],
#   ["Scanlon's Saloon"]],
#  'Cluster_5': [['Jules Goldman Books and Antiques'],
#   ["Penn's Landing Dog Park"],
#   ["Penn's Landing"],
#   ['Blue Cross RiverRink Winterfest'],
#   ['Philly Tour Hub'],
#   ["Penn's View Hotel"],
#   ['Race Street Pier'],
#   ['Philadelphia Urban Adventures'],
#   ['Cherry Street Pier'],
#   ['Shane Confectionery'],
#   ['Holiday Inn Express Philadelphia - Penns Landing']],
#  'Cluster_6': [['Drexel Park'],
#   ['Rocky Steps'],
#   ['Boathouse Row'],
#   ['The Rocky Statue'],
#   ['Lemon Hill Mansion'],
#   ['Kelly Drive'],
#   ['The Schuylkill River Loop'],
#   ['Glendinning Rock Garden']],
#  'Cluster_7': [['The Navy Yard'],
#   ['The Turf Club'],
#   ['FDR Park'],
#   ['Live Casino Hotel']],
#  'Cluster_8': [['Clark Park Dog Bowl'],
#   ['University Family Fun Center'],
#   ['Clark Park'],
#   ['Homewood Suites by Hilton University City Philadelphia, PA'],
#   ['Clark Park Flea Market'],
#   ["Bartram's Garden"]],
#  'Cluster_9': [["Leneghan's Crusader Inn"]]}

# %%
import pandas as pd

# assuming df is your DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]})

# select two columns
cols = ['A', 'B']
result = df[cols].values.tolist()

print(result)
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
